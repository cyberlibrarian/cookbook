# %% [markdown]
# # Exploring the StalkPhish.io REST API
# StalkPhish.io is a hosted service based on the open-source software version of StalkPhish. StalkPhish is handy for gathering information about phishing sites, capturing copies of the phish kits used etc. If you are doing research on phish kits, or performing incident response for phishing incidents, or gathering threat intelligence on phishing campaigns or infrastrcuture, StalkPhish is really nice.
#
# The hosted version has an API that you can use to search for information they gather. If you have you own instance of StalkPhish you can have it gather info on targets of your choice. But with StalkPhish.io you can search for info about a large existing base of information.
#
# ## API Documentation
# I used the following three sources to understand the API:
# - The FAQ: https://www.stalkphish.io/faq/
# - The API documentation: https://www.stalkphish.io/documentation/api/
# - This Blog Post: https://stalkphish.com/2021/06/30/howto-stalkphish-io/
#
# ## Purpose of this Notebook
# This notebook contains my experiments exploring the StalkPhish.io API and tests of how the API works. I have some general tests to ensure that my python works correctly with the API, but I also have experiements to see what kind of data is available.

# %% [markdown]
# # Requirements
# I will require only a few python libraries for our experiments.
#
# - "os" is used to get environment variables
# - "getpass" is used to allow the user to securely enter their API token
# - "json" to format JSON output nicely.
# - "requests" to handled HTTP GET requests and responses

# %%
import os
import getpass
import json
import requests

# %% [markdown]
# # Define the StalkPhish.io API v1 Endpoints
# Not all of the endpoints are curreently usable. This is based on the API documentation found here:
# https://www.stalkphish.io/documentation/api/
#
# According to this blog we have access to the following endpoints on the free plan.
#     https://stalkphish.com/2021/06/30/howto-stalkphish-io/
#
#     /api/v1/me : Return informations about account linked to API key.
#     /api/v1/last : Return n last results, with n depending on your subscription.
#     /api/v1/search/url : Return results of string search appearing in a URL
#     /api/v1/search/title : Return results of string search appearing in a website title.
#     /api/v1/search/ipv4 : Return results of IPv4 search.

# %%
# Stalkphish API Endpoints for API v1
ep_base_url = 'https://www.stalkphish.io/api/v1'

# me: Return informations about account linked to API key. Limited to 100 request/day, out of profile quota.
ep_me    = f'{ep_base_url}/me'

# last: Return n last results, with n depending on your subscription.
ep_last  = f'{ep_base_url}/last'

# email: Return results of e-mail found in phishing kits.
ep_email = f'{ep_base_url}/search/email' # requires a search string appended to URL

# ipv4 : Return results of IPv4 search.
ep_ipv4  = f'{ep_base_url}/search/ipv4'  # requires a search string appended to URL

# title : Return results of string search appearing in a website title.
ep_title = f'{ep_base_url}/search/title' # requires a search string appended to URL

# url: Return results of string search appearing in a URL.
ep_url   = f'{ep_base_url}/search/url'   # requires a search string appended to URL

# brand: Return results of string search appearing in a brand name.
ep_brand = f'{ep_base_url}/search/brand' # requires a search string appended to URL

# %% [markdown]
# # API Authentication
# The documentation at https://www.stalkphish.io/documentation/api/ seems to contradict the documentation at https://www.stalkphish.io/faq/. Perhaps I misinterpreted or misunderstood the API docs.
#
# I found the instructions in the FAQ work. We need to set the "Authorization" header to include a string that starts with "Token " and ends with our API key.
#
# I have also added a header for a user-agent to help the API operators identify this script should troubleshooting be required. While not required it's a good practice and polite when using a free API.

# %%
# Get the StalkPhish.io API Token from ENV or user input
if 'SP_TOKEN' in os.environ.keys():
    token = os.getenv('SP_TOKEN')
else:
    token = getpass.getpass('Enter your stalkphish.io Token:')

# When we send the token in the authorization header, we need to add the string "Token" in front.
authorization = f'Token {token}'

# It is polite to set a meaningful user-agent. If our script causes problems for the API this
# helps the operators troubleshoot so they can contact us about problems.
# In general RFC7231 says user-agent strings should follow this format:
#   User-Agent: <product> / <product-version> (<comment>)
user_agent = 'cyberlibrarian-stalkphish-test/1.0 (michael@cyberlibrarian.ca)'

# We need these headers at minimum, Authorization is most important
headers = {
    'Content-Type': "application/json",
    'Authorization': authorization,
    'Accept': '*/*',
    'User-Agent': user_agent
    }
# Out:
# Enter your stalkphish.io Token:········

# %% [markdown]
# # Tests of the API

# %% [markdown]
# ## /api/v1/me test
# This endpoint will fetch information about our account. It makes a good test to see if we authenticated correctly to the API. It is limited to 100 per day, so limit the number of times you test with it.

# %%
# Search for my account info
# We have already set the authentication information in our headers at the beginning
try:
    response = requests.request("GET", ep_me, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %% [markdown]
# ### Information about our Account

# %%
print(f'Response Code: {response.status_code}')
[print(f'{header}: {response.headers[header]}') for header in response.headers]

# Careful! The response JSON contains our API key which we DON'T want saved in the printed output.
try:
    response_json = response.json() # raises an error if response is not JSON
except Exception as e:
    print(f'Err: {e}')

response_json[0]['api_key'] = 'XXXXXXXXXXXXXXXXXXXXXXXXXX'
print(json.dumps(response_json, indent=2))
# Out:
# Response Code: 200
# Server: nginx
# Date: Tue, 01 Mar 2022 01:35:10 GMT
# Content-Type: application/json
# Content-Length: 145
# Connection: keep-alive
# Allow: GET, HEAD, OPTIONS
# X-Frame-Options: DENY, SAMEORIGIN
# X-Content-Type-Options: nosniff, nosniff
# Referrer-Policy: same-origin, strict-origin-when-cross-origin
# Cross-Origin-Opener-Policy: same-origin
# Strict-Transport-Security: max-age=15768000
# X-Xss-Protection: 1; mode=block
# Feature-policy: accelerometer 'none'; camera 'none'; geolocation 'none'; gyroscope 'none'; magnetometer 'none'; microphone 'none'; payment 'none'; usb 'none'
# Content-Security-Policy: default-src 'self' http: https: data: blob: 'unsafe-inline'
# [
#   {
#     "username": "cyberlibrarian",
#     "email": "michael@cyberlibrarian.ca",
#     "api_key": "XXXXXXXXXXXXXXXXXXXXXXXXXX",
#     "subscribed_plan": "Free"
#   }
# ]

# %% [markdown]
# ## /api/v1/last test
# The documentation says this returns the last "n" results with "n" depending on your subscription.
#
# It is unclear what this means form the doucumentation. What results? Whose results? Let's test it and find out.
#
# Conclusion: This appears to be system wide: The number of records addedto stalkphish.io. Interesting.

# %%
try:
    response = requests.request("GET", ep_last, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %% [markdown]
# ### The last queries you made with this account

# %%
print(f'Number of results fetched: {len(response.json())}')
print(json.dumps(response.json(), indent=2))
# Out:
# Number of results fetched: 30
# [
#   {
#     "siteurl": "https://www.craftservicench.ru/",
#     "sitedomain": "www.craftservicench.ru",
#     "pagetitle": "The Sandbox - A Decentralized Gaming Platform Made By Players",
#     "firstseentime": "2022-02-28T23:21:00Z",
#     "firstseencode": "200",
#     "ipaddress": "178.208.83.42",
#     "asn": "210079",
#     "asndesc": "EUROBYTE Eurobyte LLC, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://biswap.pmsuvidha.com/",
#     "sitedomain": "biswap.pmsuvidha.com",
#     "pagetitle": "School Bus Simulator Driving",
#     "firstseentime": "2022-02-28T23:20:53Z",
#     "firstseencode": "aborted",
#     "ipaddress": "45.156.22.26",
#     "asn": "56971",
#     "asndesc": "CLOUDBACKBONE, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://connecti-auonei-jp.obs0eq5.cn/",
#     "sitedomain": "connecti-auonei-jp.obs0eq5.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:20:45Z",
#     "firstseencode": "aborted",
#     "ipaddress": "155.94.169.54",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://grp02.member.rakuten-c.info/%3Fd_j",
#     "sitedomain": "grp02.member.rakuten-c.info",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:20:24Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.deflikingdoms.com/",
#     "sitedomain": "www.deflikingdoms.com",
#     "pagetitle": "Kingdoms Attack",
#     "firstseentime": "2022-02-28T23:20:03Z",
#     "firstseencode": "200",
#     "ipaddress": "185.212.71.121",
#     "asn": "47583",
#     "asndesc": "AS-HOSTINGER, CY",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://everdome.me/",
#     "sitedomain": "everdome.me",
#     "pagetitle": "Everdome",
#     "firstseentime": "2022-02-28T23:19:37Z",
#     "firstseencode": "200",
#     "ipaddress": "198.54.120.64",
#     "asn": "22612",
#     "asndesc": "NAMECHEAP-NET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://everdome.me",
#     "sitedomain": "everdome.me",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:19:15Z",
#     "firstseencode": "200",
#     "ipaddress": "198.54.120.64",
#     "asn": "22612",
#     "asndesc": "NAMECHEAP-NET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://limaplast-net.blogspot.com/",
#     "sitedomain": "limaplast-net.blogspot.com",
#     "pagetitle": "limaplast",
#     "firstseentime": "2022-02-28T23:18:56Z",
#     "firstseencode": "200",
#     "ipaddress": "142.250.184.225",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://l.wl.co/l%3Fu%3Dhttps://abre.ai/d13C%3Fuserid%3DlCSk8goX",
#     "sitedomain": "l.wl.co",
#     "pagetitle": "\u0648\u0627\u062a\u0633\u0627\u0628",
#     "firstseentime": "2022-02-28T23:18:38Z",
#     "firstseencode": "200",
#     "ipaddress": "185.60.216.15",
#     "asn": "32934",
#     "asndesc": "FACEBOOK, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.netzvid.online/",
#     "sitedomain": "www.netzvid.online",
#     "pagetitle": "Home | Trader Joe",
#     "firstseentime": "2022-02-28T23:18:08Z",
#     "firstseencode": "200",
#     "ipaddress": "162.0.215.23",
#     "asn": "22612",
#     "asndesc": "NAMECHEAP-NET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.benbkripto.com/",
#     "sitedomain": "www.benbkripto.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-28T23:17:42Z",
#     "firstseencode": "200",
#     "ipaddress": "104.21.2.180",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.benbkrypta.com/",
#     "sitedomain": "www.benbkrypta.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-28T23:17:18Z",
#     "firstseencode": "200",
#     "ipaddress": "188.114.97.7",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://ftp.cnc.fr/DK-B%3F",
#     "sitedomain": "ftp.cnc.fr",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:17:12Z",
#     "firstseencode": "404",
#     "ipaddress": "185.113.40.118",
#     "asn": "12601",
#     "asndesc": "CEGEDIM, FR",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://post-ch.auth-ch.com/213273671",
#     "sitedomain": "post-ch.auth-ch.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-28T23:17:04Z",
#     "firstseencode": "aborted",
#     "ipaddress": "188.114.97.7",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.disontroiemd.com/",
#     "sitedomain": "www.disontroiemd.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-28T23:16:41Z",
#     "firstseencode": "200",
#     "ipaddress": "172.67.220.33",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.docentroland.com/",
#     "sitedomain": "www.docentroland.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-28T23:16:35Z",
#     "firstseencode": "aborted",
#     "ipaddress": "104.21.17.213",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://connecti-auonei-jp.kekut6t.cn/",
#     "sitedomain": "connecti-auonei-jp.kekut6t.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:16:14Z",
#     "firstseencode": "200",
#     "ipaddress": "155.94.169.54",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://connecti-auonei-jp.i5ntvux.cn/",
#     "sitedomain": "connecti-auonei-jp.i5ntvux.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:15:58Z",
#     "firstseencode": "200",
#     "ipaddress": "155.94.169.54",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://connecti-auonei-jp.j783wl0.cn/",
#     "sitedomain": "connecti-auonei-jp.j783wl0.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:15:49Z",
#     "firstseencode": "200",
#     "ipaddress": "155.94.169.54",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.r.masternsacorrcarnd.com/",
#     "sitedomain": "www.r.masternsacorrcarnd.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:15:38Z",
#     "firstseencode": "200",
#     "ipaddress": "107.172.249.18",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www2.masternsacorrcarnd.com/",
#     "sitedomain": "www2.masternsacorrcarnd.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:15:25Z",
#     "firstseencode": "timeout",
#     "ipaddress": "107.172.75.136",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://polygon.weblogin.click/",
#     "sitedomain": "polygon.weblogin.click",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-28T23:15:04Z",
#     "firstseencode": "200",
#     "ipaddress": "179.43.156.178",
#     "asn": "51852",
#     "asndesc": "PLI-AS, PA",
#     "asnreg": "lacnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://aiu.kdda.fvdgr.xyz/au.php%3Ftoken%3De8d1c4bc3abb0a5a2348c53f9ff",
#     "sitedomain": "aiu.kdda.fvdgr.xyz",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2022-02-28T23:15:01Z",
#     "firstseencode": "404",
#     "ipaddress": "34.97.207.128",
#     "asn": "396982",
#     "asndesc": "GOOGLE-PRIVATE-CLOUD, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://aiu.kdda.fsgvb.xyz/au.php%3Ftoken%3Dff9b652cd606fffe84a8ffcdfa3",
#     "sitedomain": "aiu.kdda.fsgvb.xyz",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2022-02-28T23:14:57Z",
#     "firstseencode": "404",
#     "ipaddress": "34.97.207.128",
#     "asn": "396982",
#     "asndesc": "GOOGLE-PRIVATE-CLOUD, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://aiu.kdda.bvdfe.xyz/au.php%3Ftoken%3D5655cebe0e5301be12a7d343569",
#     "sitedomain": "aiu.kdda.bvdfe.xyz",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2022-02-28T23:14:53Z",
#     "firstseencode": "404",
#     "ipaddress": "34.97.207.128",
#     "asn": "396982",
#     "asndesc": "GOOGLE-PRIVATE-CLOUD, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://mettamasc.com",
#     "sitedomain": "mettamasc.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:40Z",
#     "firstseencode": "timeout",
#     "ipaddress": "172.67.151.192",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://metamaskwebapp.com/",
#     "sitedomain": "metamaskwebapp.com",
#     "pagetitle": "MetaMask",
#     "firstseentime": "2022-02-28T23:14:31Z",
#     "firstseencode": "200",
#     "ipaddress": "161.35.218.92",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://openseca.com",
#     "sitedomain": "openseca.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:18Z",
#     "firstseencode": "timeout",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://illuviumbeta.com/",
#     "sitedomain": "illuviumbeta.com",
#     "pagetitle": "Illuvium",
#     "firstseentime": "2022-02-28T23:14:12Z",
#     "firstseencode": "aborted",
#     "ipaddress": "45.130.41.31",
#     "asn": "198610",
#     "asndesc": "BEGET-AS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://roninwailet.com",
#     "sitedomain": "roninwailet.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:04Z",
#     "firstseencode": "aborted",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations on /last test
# Generally, the API results seem to be in this format. Will all endpoints produce this same type of record or will more context be available?
#
# `
#   {
#     "siteurl": "http://openseca.com",
#     "sitedomain": "openseca.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:18Z",
#     "firstseencode": "timeout",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
# `

# %% [markdown]
# ## /api/v1/search/email/ test
# This endpoint will search for e-mails found in phishing kits. It is unclear if this means emails referenced in the phishkit code (e.g. emails used for collection of phished credentials) or if it means emails found in victim dumps in captured phishkits. Or perhaps it refers to emails referenced in phishing URLs (some phishing URLs contain the victims email address)

# %% [markdown]
# In our test we are going to search for a list of email address. These fall into several categories:
# - Addresses that have sent phishing links in the past (compromised or attacker emails)
# - Addresses that have been observed in phishing links (known victim emails)
# - Addresses that have received phishing emails (but not mentioned in actual phishing URLs)
# - Addresses that have send maldocs (compromised or attacker emails)
# - Addresses that have send test emails (during preparation of new gmail.com accounts)

# %% [markdown]
# ### Test 1: with 1 emails: one expected known to send phish, one known safe

# %%
# Test emails
emails = [
    'michael@cyberlibrarian.ca',
    'thamaraiselvan.m@ionexchange.co.in'
]

# Make a separate query for each email. 
responses = []
for email in emails:
    url = f'{ep_email}/{email}'
    try:
        response = requests.request("GET", url, headers=headers)
        responses.append(response)
    except Exception as e:
        print(f'Err: {e}')

# %%
print(f'Number of responses: {len(responses)}')
for response in responses:
    print(f'Respnse Status: {response.status_code}, {response.json()["detail"]}')
# Out:
# Number of responses: 2
# Respnse Status: 429, Request was throttled. Expected available in 81789 seconds.
# Respnse Status: 429, Request was throttled. Expected available in 80164 seconds.

# %% [markdown]
# ### Observations on /email test
# I guess this does not work for the free API. "You don't have access to this search option with you profile"
#
# Initially we sent 14 requests, and ended up throttled after a few attempts to troubleshoot.
#
# response.status_code=429 means we were throttled. What other status_codes are there?

# %% [markdown]
# ## /api/v1/search/ipv4/ test
# This endpoint allows us to search ipv4 address. But are these IPv4 addresses of sites hosting phishing sites? Or IPv4 addresses associated with phishing email senders?

# %%
# Search for IPv4 (46.101.222.88)
ip = '46.101.222.88'
for ip in ips:
    url = f'{ep_ipv4}/{ip}'
    try:
        response = requests.request("GET", url, headers=headers)
    except Exception as e:
        print(f'Err: {e}')

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "detail": "Request was throttled. Expected available in 85165 seconds."
# }

# %% [markdown]
# ## /api/v1/search/title test
# This searches for titles in web pages. Presumably in the pages for phishing sites. This would be great for cases where we have found a phishing site and want to see where else it has been used.
#
# For our test we will use several strings for titles we believe are unique: representing things we expect and DO NOT expect to find in phishing sites.

# %%
# Search for Page Titles
titles = [
    'cyberlibrarian',
    'wawanesa',
    'O365',
    'Mail Center',
    'Dropbox'
]
responses = []
for title in titles:
    url = f'{ep_title}/{title}'
    try:
        response = requests.request("GET", url, headers=headers)
        responses.append(response)
    except Exception as e:
        print(f'Err: {e}')

# %%
print(f'Number of responses: {len(responses)}')
for response in responses:
    print(f'Respnse Status: {response.status_code}, {response.json()}')
# Out:
# Number of responses: 5
# Respnse Status: 401, {'error': "You don't have access to this search option with you profile"}
# Respnse Status: 401, {'error': "You don't have access to this search option with you profile"}
# Respnse Status: 429, {'detail': 'Request was throttled. Expected available in 80423 seconds.'}
# Respnse Status: 429, {'detail': 'Request was throttled. Expected available in 80422 seconds.'}
# Respnse Status: 401, {'error': "You don't have access to this search option with you profile"}

# %% [markdown]
# ### Observations for /title test
#
# response.status_code=401 occurs when you don't have access to this search option.
# The response will contain a JSON/dict item called "error" with value "You don't have access to this search option with you profile"

# %% [markdown]
# ## /api/v1/search/url test
# This endpoint allows us to search URLs. It is not clear if we have supply a full URL or a string to search for in an URL. I think "string to search for".
#
# So for our first experiment we will search for a single string we expect to find results for.

# %%
# Search for emails containing "cyberlibrarian"

url_string = 'o365'

url = f'{ep_url}/{url_string}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Response Status: {response.status_code}')
print(f'Headers: {response.headers}')
print(f'Number of results: {len(response.json())}')
print(json.dumps(response.json(), indent=2))
# Out:
# Response Status: 200
# Headers: {'Server': 'nginx', 'Date': 'Tue, 01 Mar 2022 02:05:29 GMT', 'Content-Type': 'application/json', 'Content-Length': '33993', 'Connection': 'keep-alive', 'Allow': 'GET, HEAD, OPTIONS', 'X-Frame-Options': 'DENY, SAMEORIGIN', 'X-Content-Type-Options': 'nosniff, nosniff', 'Referrer-Policy': 'same-origin, strict-origin-when-cross-origin', 'Cross-Origin-Opener-Policy': 'same-origin', 'Strict-Transport-Security': 'max-age=15768000', 'X-Xss-Protection': '1; mode=block', 'Feature-policy': "accelerometer 'none'; camera 'none'; geolocation 'none'; gyroscope 'none'; magnetometer 'none'; microphone 'none'; payment 'none'; usb 'none'", 'Content-Security-Policy': "default-src 'self' http: https: data: blob: 'unsafe-inline'"}
# Number of results: 50
# [
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D14e1a2bb-f887-0e4f-7951-b9009dea7b6f%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637816299138232509.6d434649-a21f-4718-97dc-0f1c74fe5bdf%26state%3DfU9dT4MwAAT9LdsbjkIL9IGYYotBVxdI4xxvfBQzBhIHUrL_uf9j5w_wkrvkLncPZxqGca95p2naWgzfc_0AeA7GwA0c10E2fvBq6EIPYqtwQGNBHwQW9uvKshtQ-bCRqKwbU2-v5mZQxeYxmWSf0JAQfiI0veRt3PP-pd0K5nLBpjdaXQ5HG-1EprOozWne7QSDeZuqQxo9kz88DeSV8q8SKYFY7rMyWz7eVaSilRPvoSoXtD-LYjuzPtFJLCemR-yb3Bwh_7X4CZUR1u2VS9dymcefcxeC9XyUqh9q2YWZLGoux7H4lLcrvw%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-28T07:45:06Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.132",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://quizz247.com/admin/O365auth%2520reviewdata%2520memorystick/",
#     "sitedomain": "quizz247.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2022-02-26T12:50:33Z",
#     "firstseencode": "404",
#     "ipaddress": "162.214.123.240",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Dee2fd7ed-3dc4-dad8-cf9d-7c1ea3757e8b%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637814559083702422.74bcdcbf-5f22-427d-981e-b456a6364094%26state%3DfU9dT4MwAAT9LdsbDkpL4YGYYovBrS6Qxjne-OgMCBIHUrL_uf9j5w_wkrvkLncPZxqGca95p2naWgzsudh3IEKB7bvYBhCABwzLqq7Kk4VOAFgQ4NoKfEdaJURe4bketANo6u3V3Ayq2Dwmk-wTGhLCPwlNL3kb97x_aXeCuVyw6ZVWl2Njo73IdBa1Oc27vWAwb1N1TKNn8oengWwp_yqREojlmJXZ8v6mIhWtQHyAqlzQ4SyK3cz6RCexnJgesW9yc4T81-LNrLaRbq9cupbLPP6cu9BZz41U_VDLLsxkUXM5jsWHvF35BQ%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-26T08:44:04Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.69",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://sso.godaddy.com/%3Fdomain%3Dcapitalonemotor.com%26realm%3Dpass%26app%3Do365%26client-request-id%3D98d9520f-9a78-d59d-6bf7-c9b9159b74da%26username%3D%26wa%3Dwsignin1.0%26wtrealm%3Durn%253afederation%253aMicrosoftOnline%26wctx%3Destsredirect%253d2%2526estsrequest%253drQIIAY2RPWwSYQCG7-PoCfWnRGPiYmIaJ-NxHN_9QeIAHC0IBxcqtLCQ47ijx8F9x90HlO4mbjZxMZh2cGR00i662sGwONjJsWkcGmNiY4yxxMWxz_DmTd7teR-QbJRN3o_9I04vko6ZJkvrxqL9h3dzObJS-fJyZ7r_2f758d3tV_h4Cm7pmmthrYcco48w8qI66s_A6jbGrp9kGDTEPYTsKDJNSzegwC92Bo015i0AcwBOAJgFRAGKEsvxAifGOMjHhQQX5bWWCNscpE2dbdNcopWgExKfoHlOj7egDhOiZhwHVsqpId6OLwJ51q7xPRA2kddvusjHU_IFkHX8WPaVjpxNV7RycyPX6Pn5NT6r1v1Gwa4W2tWKa4ziEyPXhLhWHEAcE1SzikQpM1LYQc60C2NroujFlK5m9HWJc8dK1UrLg0mtq2xw6bwrO57qi91RsSvV7N1cfLNoloWSDB0nb8NBtlCVPO_JDo45msquD7dUaUZeyvYbkrow1UfOEUkh13Cs9jwIvgbBafBajEyGQssR4g5xjzgPgtdLF8d8wt27v0-HhYPC-7rw4yFxtMRYjKSsdRpKnkvJslFit-qlDrKKXroD64ygtSCDe3Ijw_rK-JGYZPcosEdRh1Q4REaIVTKjsicUOKPAsyvEYfgSf86vgg_XifMbT8_2n_86-PMt9xc1",
#     "sitedomain": "sso.godaddy.com",
#     "pagetitle": "GoDaddy DE Seite nicht gefunden (Fehler 404) GoDaddy DE",
#     "firstseentime": "2022-02-26T08:00:03Z",
#     "firstseencode": "403",
#     "ipaddress": "23.45.102.212",
#     "asn": "16625",
#     "asndesc": "AKAMAI-AS, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://login.verify.o365.networkchain.my.id",
#     "sitedomain": "login.verify.o365.networkchain.my.id",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T11:10:57Z",
#     "firstseencode": "500",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D4e5925bb-e531-8abd-c0c3-9787afcfb69a%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637813578531804913.7eb1217a-d6c9-4a14-948a-add7a825d292%26state%3DfU_RToMwAAT9lu0NR6Fd4YGYYotBVxdI4xxvZW0MCBIHUrL_9H_s_AAvuUvucvdwruM4t5Y3lq5vxcHbEEcgRDhCIYh8GIPwDusaBABLT21PsQclgF4MI-lJpbCMAqSCOHDt9sfdDEZu7vNJ9zlNCOEfhBaXqs163j-1O8FCLtj0Qk-XY-OjvShtlrYVrbq9YLBqC3Ms0kfyh4eBPFP-WSMjEKswq8vl7dWkJl0F2QGaekGHs5C7mfW5TTI9MTtiX-TqCPmvxZvZ5IVtr0K61ss8fp-7BKznRpt-ULpLSi0V1-Mo3_X1yi8%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-25T03:51:48Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.8",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.linkedfam.com/admin/O365auth%2520reviewdata%2520memorystick/",
#     "sitedomain": "www.linkedfam.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T02:30:56Z",
#     "firstseencode": "404",
#     "ipaddress": "162.241.159.36",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.linkedfam.com/admin/O365auth%2520reviewdata%2520memorystick",
#     "sitedomain": "www.linkedfam.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T02:29:54Z",
#     "firstseencode": "404",
#     "ipaddress": "162.241.159.36",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.linkedfam.com/admin/O365auth%2520reviewdata%2520memorystick",
#     "sitedomain": "www.linkedfam.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T02:29:54Z",
#     "firstseencode": "404",
#     "ipaddress": "162.241.159.36",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://gynaecologistchennai.com/office/O365auth%2520reviewdata%2520memorystick/",
#     "sitedomain": "gynaecologistchennai.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T02:09:53Z",
#     "firstseencode": "404",
#     "ipaddress": "142.4.5.237",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.verify.o365.networkchain.my.id",
#     "sitedomain": "www.verify.o365.networkchain.my.id",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T00:58:50Z",
#     "firstseencode": "200",
#     "ipaddress": "142.93.6.96",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.verify.o365.networkchain.my.id",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T00:38:17Z",
#     "firstseencode": "200",
#     "ipaddress": "142.250.184.238",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://login.secure.work.o365.hana-arifiani.xyz",
#     "sitedomain": "login.secure.work.o365.hana-arifiani.xyz",
#     "pagetitle": null,
#     "firstseentime": "2022-02-24T11:13:18Z",
#     "firstseencode": "timeout",
#     "ipaddress": "159.223.175.235",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://get.armorblox.com/phishing-google-o365-workspace-blog%3Futm_source%3Demail%26utm_medium%3Dnurture%26utm_campaign%3DEC%2B20220126%2BPhishing%2BMOFU%2BMini%2BNurture%26utm_content%3Demail1%26mkt_tok%3DMTc2LVhNSi0wMzAAAAGCeh7RIjS2fz4hEPpqmjPsNK2a3pfm4DU04fLG7c55vkW944D7ubi_KfrTgQIAvv5tqHByoVtk8ZWt_JEnGdl2FPUbRbLiBFUtQ7XokfcKMg",
#     "sitedomain": "get.armorblox.com",
#     "pagetitle": "Pageserver 404",
#     "firstseentime": "2022-02-24T06:42:13Z",
#     "firstseencode": "404",
#     "ipaddress": "107.178.254.45",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.secure.work.o365.hana-arifiani.xyz",
#     "sitedomain": "www.secure.work.o365.hana-arifiani.xyz",
#     "pagetitle": null,
#     "firstseentime": "2022-02-24T06:21:45Z",
#     "firstseencode": "aborted",
#     "ipaddress": "159.223.175.235",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.secure.work.o365.hana-arifiani.xyz",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-24T06:14:08Z",
#     "firstseencode": "aborted",
#     "ipaddress": "142.250.184.238",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://10.16.168.211/Home/misc/Knowledge_Series/html/index.html%3Futm_source%3DICICIBank%26utm_medium%3Demail%26utm_campaign%3DO365-mobile_support-Internal-Mailer%5D",
#     "sitedomain": "10.16.168.211",
#     "pagetitle": null,
#     "firstseentime": "2022-02-24T04:34:25Z",
#     "firstseencode": "500",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.landingo365.spotfig.cc",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-23T23:28:24Z",
#     "firstseencode": "200",
#     "ipaddress": "216.58.212.142",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Dc9d97e1d-e6da-6578-08ca-97c422afee69%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637812543134999222.87682d6d-0a93-4142-9d13-612ac91a0cc3%26state%3DfU_LToNAAAT9lvaGZR889kDM4i4GLTaQjbXcFtgYECQWZEn_0_9x6wc4yUwyk5nD2JZl3RreGNquESvwURAC6GEEECaEQAjvwsAPYeM3jisJcjDA0CENQI4PoKwJkG5dI9tsf-zdqOXuPp3VkLKI0uyDsvxSdsmQDU_dXnCUCT6_sPpyal3vIAqTxV3Jyv4gOC67XJ_y-JH-4WGkzyz7rDwtPF4GvCrWt1cd63gDkyPW1eodz0LuFz6kJknUzM2If9Gro_S_VtbGoO9Ne4PYVq3L9H3uI7BdWqWHsVF9VCjZZGqa5Lu6XvkF%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-23T23:06:33Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.159.132",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://account.o365-tensarcorp.com",
#     "sitedomain": "account.o365-tensarcorp.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-23T13:07:12Z",
#     "firstseencode": "aborted",
#     "ipaddress": "167.71.24.83",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D6d4ae309-3fb2-e1c1-00b1-cd269c9fdd1c%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637812063116945346.24e67323-6416-4367-89ca-63c7bb7d9cea%26state%3DfU_RToMwAAT9lu0NB7S044GYYsvErS6QxjneCjTLECQOpGT_6f_Y-QFecpfc5e7hbMuy7g3vDG3XiIURwGvPdxHwPBTCAED04EOFMPCBg6CHHAgQdtZhJR0EKlyWuA4rJW2z_bFXvZarx3RUXUojQvgHodm1aJKOdy_NTjDABRtfaXU9nt1gL3KTxU1Bi3YvGCyaTB-zeEP-8NSTLeWfZaBFwArMynx-f9Oxjhd-coC6nIPDRcjdxLrUJIkamRmxL3JzhPzX4qeNfN6a9gLQpZqn4fvSRt5yOivd9bVqo1zJmqthkCd1u_IL%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-23T10:35:38Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.143",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D47db602f-90a2-fab7-6df8-e7de24e68547%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637812063750996054.b746b19d-abb7-4042-a65c-903100b71109%26state%3DfU9RT4MwGAT9LdsbrkBL5YGYYstEqQukcY63djTLECQOXMn-p__Hzh_gl9xd7nL38LmO49xa3Fi4wJKDoxDf-wGwgkAcRwDBO4VhpPy48aRS2IMABp6M0N6LQegDoLDvg9i12x93NRi5esgn3ec0IYR_EFpe6jbref_cFoKFXLDple4vuyNAG1HZLG1rWncbwWDdlmZXpmvyd48DeaH8UyEjEKsxU9X8_mZSky6CbAuNmtH2JGRxZn1uk0xPzI7YF7k6Qv5r8cNaPhW2vQjpUs_n8fvUJf7yfNSmHxrdJZWWDdfjKA_6-sov%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-23T10:29:04Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.75",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Dc477d414-94d4-176f-d0e1-9f00a77f4168%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637812066660180505.37cfeea7-a961-44c5-8034-25140534db27%26state%3DfU_RToMwAAT9lu0NV6Cl-EBMsWXiVhdI4xxvBeoyBIkDKdl_-j92foCX3CV3uXs427KsW8MbQxsYsXDg49D1QGAA3BAggO58XL0rJbEj7wPXgbBCTgh86HjIhQD5sC49bJvtj73qtVw9pKPqUhoRwj8IzS5Fk3S8e262gvlcsPGFVpfDCaCdyE0WNwUt2p1gsGgyfcjiNfnDY082lH-WSAvECszKfH571bGOF16yh7qc0f4s5HZiXWqSRI3MjNgXuTpC_mvx41o-cdNe-HSp5mn4PreRu5xOSnd9rdooV7LmahjkUV2v_AI%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "One moment, please...",
#     "firstseentime": "2022-02-23T09:55:49Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.137",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Da71e1ea6-b8a5-988c-c8b8-7932f266edff%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637811688720609381.da11362e-c87c-4c00-a764-5e18a48ba73c%26state%3DfU_RToMwAAT9lu0N11Kg9YGYYgtBVxcIcY63As0yBIkDKdl_7n_s_AAvuUvucvdwtmVZ94Z3hjYwYuEAYQJhQAh2QQAeEYEPjYQQBa5yaoJrx6sBcCQOPMdXkEiPVBKj2jbbq70ZtNw8pZPqUxZSKj4pyy5lG_eif2m3BUei4NMbqy-HE_B3RW6yqC1Z2e0K7pVtpg9ZlNA_PA_0lYmvyteFz0vMq3z5eNeRjlZuvPd0tfj7cyG3M-9Tk8Rq4mbEv-nNUfpfSxwTmUymvUJsrZZ5_Dl3IVzPJ6X7oVFdmCvZCDWO8qhuV34B%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-22T23:43:24Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.6",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.o365.officeservicess.ml",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-22T23:27:16Z",
#     "firstseencode": "aborted",
#     "ipaddress": "142.250.185.206",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D236fe85b-beb1-05b9-8981-cd5d40303052%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637811544150038674.96331ed2-7674-4f9e-950a-f77fe8074deb%26state%3DfU_hToMwGAR9lu0frqwthR_EFCkLurpAGuf4V6QsQ5A4kJK9p-9jtwfwS-5L7nKXy9mWZd0b3BnYwDyLeJD4rosRcjEA0PcIegg8CF1VrR1imIPqQDkBBtKpCamVDwiqVGmb7K-96rVcPaaj6tI4pJR_0ji7FE3S8e652QoGuWDja_xxOZwA3oncaFFTxEW7EwwVTaYPWbSht3vq6UvMv0qsBWYFYWU-v7_pSEeLdbJHupzx_izkdmJdapREjcyE2De9Mkr_c_HjRt5KFjBeqnkafs5t6C6nk9JdX6k2zJWsuBoGeVTXKX8%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-22T19:22:50Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.2",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.o365.lb-is.net",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-22T10:12:32Z",
#     "firstseencode": "aborted",
#     "ipaddress": "142.250.184.238",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://pages.egress.com/whitepaper-idcvendorspotlight-0620-o365.html.html%3Futm_campaign%3DWhitepaper-IDCVendorSpotlight-0620%26utm_medium%3Demail%26utm_source%3Dmarketo%26mkt_tok%3DMzQ0LVhURC02ODQAAAGCpvUnVcurQ7CtfBSwxfbP_BeVdkZuXoTHtmQl2yOpWouqi3h5o6OK_ZwvsXRPrMCBoIt-ekG64mWRgRQj67DkRoF2sptAyLYIxq01r9RO0g",
#     "sitedomain": "pages.egress.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-21T10:47:34Z",
#     "firstseencode": "200",
#     "ipaddress": "104.17.73.206",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Dae85db01-6cd9-4413-4487-f7293d136b15%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637810323744254807.2ba9096d-d3d2-4c99-8f66-44346e63480c%26state%3DfY_RToMwGIVBn2W7wzFaWrggpqxlQVcXSOMcdwXqMgSJAynZe_o-dj6AJzkn-U--c_HblmXdG98Z264JCyOAg7ULPIAh9HwYuPjBK2Xohqh2alB7DqzC0AneEXIgBBApBAxU2Wb7Y696LVeP6ai6lEaE8A9Cs2vRJB3vnpqdYIALNr7Q6no8u_5e5KaLm4IW7V4wWDSZPmbxlvxp05Nnyj9LXwufFZiV-fz2qmMdL7zkAHU5-4eLkLuJdalpEjUyM2Jf5HYR8h_FT1u5iQ29AHSp5mn4vrTRejmdle76WrVRrmTN1TDIk7q98gs%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-21T09:58:27Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.2",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://qa8760.dinero365.ph",
#     "sitedomain": "qa8760.dinero365.ph",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T08:49:10Z",
#     "firstseencode": "200",
#     "ipaddress": "51.124.12.35",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.o365.findstr.top",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T08:34:15Z",
#     "firstseencode": "200",
#     "ipaddress": "142.250.184.238",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://sso.godaddy.com/%3Fdomain%3Dcapitalonemotor.com%26realm%3Dpass%26app%3Do365%26client-request-id%3Dac1af392-4e42-f222-071d-81ef364006ce%26username%3D%26wa%3Dwsignin1.0%26wtrealm%3Durn%253afederation%253aMicrosoftOnline%26wctx%3Destsredirect%253d2%2526estsrequest%253drQIIAY2RP4jTYADF8zW9XHt6WnRRQZCii_K1-dPmSwqCramktOm_u-q1S0lzSS60yZemX3tettscD926CI7FyUluOnC7QbqekzgdIiinwzkItrg43hseD97yeL_7NJficnfZf-Lh0iFrWRw0zGX6T8G1tcTLn7feFqrJs9Xb-9_FR8zHKbhu6L5D9AH2TBcTHKQM7M5AcocQf5RLp_GYDDDup7BlOYYpiNlln8a7evo9AHMATgGYRZAoIIljOZTN8LwsymJWTpm6ZXIyi6Bk9BDMsFwP6lzGgj20GKb3BMlExqfI1Vp-THb4peHACc2zSNzCgdv18YhM6VdAMUhBwZpdLBaaeq27oTbKZcV5roVhWWvzJcdrdzbMLr9nql2BPK0MBcKKaAu3KoVqEYWh1m6Gm32_nVXauwjCzXxT8217Uu_gPER7LWWkFWHT3mp2g07L4t3tQV0jZahkdG9ScUp9Ydh4UjI51HOINOCtoj0OPGlGX-jtdzSzeMrF3jHNYN_0nO15FHyOgq_Ryyydi8XWEtQN6g51HgVvVhZg7n1IrP8qPCjsh9RvcrMMjlfSDXkwtJ1RrdFSuEalUtXcTU0eqc-kAOtI1atDVe-oblZUJ_ZDMccdMOCAYQ6ZeIxOUEn6cZ07ZcAPBrxYpQ7jF-A5vwSO1qnzK0cnJ1-mr_98U_8C0",
#     "sitedomain": "sso.godaddy.com",
#     "pagetitle": "Access Denied",
#     "firstseentime": "2022-02-21T05:22:50Z",
#     "firstseencode": "403",
#     "ipaddress": "23.45.102.212",
#     "asn": "16625",
#     "asndesc": "AKAMAI-AS, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Dd6a5894a-7960-c279-f8f7-123af1ace86d%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637810017536789577.bcedab25-57f9-4bc9-9fb4-b0214d581936%26state%3DfU_LboMwAIPtW9obK68QOKApLKFia1aBonbllkBalcHQCiOo_7n_WboPqCVbsmUfbBqG8aj5oGnaWgwYeDB0bNuBwAtgGAEIn0Qlay5cYAF4jCxfVJEVHYVvCdt1_BqETuQFpt7-mqte8dVzNsouwzFC9BPh_Fo2aUe712bDiEcZGd9xdT2cbbBlhc6SpsRlu2XEL5tcHfJkjf7x0qM3TL8EUAyQEhJRzB87lahk4aZ7X4kZ7C-MbybSZTpJ5Uj0iHyjm0PoXoue1hwp3V54eCnnafi5tLGznM5SdX0t27iQvKZyGPhJ3q78AQ%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-21T02:12:10Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.135",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D5230e1b8-a318-42a4-d80d-3a085004a01f%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637810017538624470.690c0cd4-e18b-4fae-80a1-72be9d3dd126%26state%3DfU_RToMwAAT9lu0N10Kh7IGYImVBVxdI4xxvhdZlCBIHUtx_-j92foCX3CV3uXs427KsW8MbQxsYsXDg4RACALHvhYGLEAZ3wRrUoJbIUTCsHPQmlBMCAR3sVmotPSmhG9hm-2Ovei1W99mouiyJCGHvJMkvZZN2rHtstpx6jNPxOakvhxPwd7wwWdyUSdnuOEVlk-tDHm_IHx568pSwj8rX3KclplUxv77oWMcLN90jXc3-_szFdqJdZpJUjdSM6Ce5OkL-a7HjRpBv0154yVLN0_B1biO4nE5Kd71UbVQoIZkaBnFU1yu_%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-21T02:12:08Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.141",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D3b2762ca-e630-9a88-bd09-16953427d088%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637810017544170706.f30bcb44-7080-418b-8138-fa21e856a62d%26state%3DfU_RToMwAAT9lu0N10JLeSGm2LKgwwXSOMdbO7plCBIHUrL_9H_s_AAvuUvucvdwruM495Z3li6w4pAwIBEEABKMECSAgPDhGAB1UAh5BETAQzBSXgSDyDtKH-oIhzL0a9duf9xVb-TqMRt1l7GY0vyDsuJaNWmXd8_NRvAgF3x8ZYfr_gzwVpQ2S5qKVe1WcFQ1hdkXyZr-4amnLyz_VNgIzCvCVTm_v5nEJAs_3SGjZry7CLmZeJfZJNUjtyP-RW-O0v9a-Wkt6Wzbi4At9TwN35c2hsvprE3X17qNSy3rXA-DPOnblV8%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-21T02:12:03Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.2",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Dff693f3b-f9de-3b03-83fe-4861b2db708a%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637810017560671118.d5dffc39-5dd0-4805-96b9-d642741c20ca%26state%3DfU_RToMwAAT9lu0N1wKl8EBMkbKgq8tI4xxvhXbLECQOpGT_6f_Y-QFecpfc5e7hbMuy7g3vDG1gxMKBh0MIAMQoAAGGEIYPEsnjsfYiB0kJHD8EyImCKnJk4LvYh7ULamGb7Y-96rVYPeaj6vI0JoR9kHR3LZusY91zs-HUY5yOr2l9PZwB2vLCZElTpmW75dQvm50-7JI1-cNTT15S9lkhzREtMa2K-f1NJzpZuNne19WM9hcuNhPtcpNkaqRmRL_IzRHyX4ud1oJMpr3w0qWap-H70sZwOZ2V7nqp2rhQQjI1DOKkbld-AQ%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "\u30ed\u30b0\u30a4\u30f3 | \u30a4\u30aa\u30f3\u30ab\u30fc\u30c9 \u66ae\u3089\u3057\u306e\u30de\u30cd\u30fc\u30b5\u30a4\u30c8",
#     "firstseentime": "2022-02-21T02:12:01Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.159.134",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://sso.godaddy.com/%3Fdomain%3Dcapitalonemotor.com%26realm%3Dpass%26app%3Do365%26client-request-id%3Da3052132-a59a-00fe-7613-144b4ac0153b%26username%3D%26wa%3Dwsignin1.0%26wtrealm%3Durn%253afederation%253aMicrosoftOnline%26wctx%3Destsredirect%253d2%2526estsrequest%253drQIIAY2RO2zTUABF_erEJOUXUZAQExQmkOP3Yju2gxiSOE2a0KbpLzJL5Pibn18SvzSfHYkFqRILyghiyQgL6tQRdcqCQAwIMRXEgJCQwgCiEQtjz3B1pbude5tGUZS4Bf8RY-fJQttGrGHN2390Ly1GYjeCz8cv_lB7S5cL-cMrd8dgydDbNaI3sWe1MMHdqIFbE7DsEtL2ExyHe6SJcSOKbbtmWHxcnO8c7uvcawCmABwDMFmQ4rwkQ4WHcRFBBQlIVKK2btmCYgqsjiSFFVDcZJWYobC6qSiGCWXRiskfFi4Wkz3ixuaBu7WR9WMhbONuq9LGPhnTT4BqkHUVrzmZTMrt5Oy26uSa1UE168O-tp0ZNiBKdbpILvOKrxS0Lc31DWek1VY1jc_3s5006eu-P5BaSXnPdfKDdBZmxCyspxqNjJssl4bDB0ZzaK90RtuVHWtIBLTF11l2IMg62ZHIqDXa2BWhULVH3ia7RthmpZSZ0Key_ZJmTky1sHdEM7hteTVzGgCfAuBr4BykE6HQYoS6Sl2nZgHwLHhyzOfqr5tvrr0vjN-9mr3FReooyJG4sOqZKaec9HrcnTLUBUNd2VW1okMKg03eFuvrVul-XW1wpXtSAu0zYJ9hDphwiI5Qy3R6Ax0z4DsDHp2hDsKn-HN6Fhyep2YXHn98-uXnw9_fcn8B0",
#     "sitedomain": "sso.godaddy.com",
#     "pagetitle": "Access Denied",
#     "firstseentime": "2022-02-20T05:21:28Z",
#     "firstseencode": "403",
#     "ipaddress": "23.45.102.212",
#     "asn": "16625",
#     "asndesc": "AKAMAI-AS, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://sso.godaddy.com/%3Fdomain%3Dcapitalonemotor.com%26realm%3Dpass%26app%3Do365%26client-request-id%3Db14eb859-24ec-f9fb-4695-a252e167e237%26username%3D%26wa%3Dwsignin1.0%26wtrealm%3Durn%253afederation%253aMicrosoftOnline%26wctx%3Destsredirect%253d2%2526estsrequest%253drQIIAY2RP2wSYQDF7-PoFapVooujaepictx3fMdxR-IAlB6U_4UU6NLcXzj-fQf30SK7iWMTdam6dJNNp6aDOjMxGwc1DtV0ME5tGhMhLo59w8tL3vTe7yHNB_noOvynELtwFloWz-rmIv2nwZ2VQP0k__Z8_epy88Xx9tfGt8gRuKurjk3UDu6ZXUzwIKjj7gSsNQlx3CjH4SHpYNwOYsuydROJ4UXP4QOVOwFgBsAZABNPREQRCcoIRlAYyiEkIDkYEQxLhxCxmihZrKAjgZW0MGRNGcmCwQumasJPntuF2JA0QwvDA3ts_vb4LTzo7jnYJUf0M7Chk_iGm24kk_FtmB0KWBgXSC5hS-VRpZvYzVddvcEP97PCPjKIpNZVZDnZYrmeU5R0Ox5LtJyYWd6ylZJSy8cKdjWjioWck8k-PmgWkna9b4zSVbeI-Fpvz-3xO0KR1XLzNaOBLYWJ0jbcpohcaSxpO_1QRd6tiE1pQl_r7Xc0M3-qi3tTmsGO2bONmRd88YKf3puQjvp8KwHqHnWfuvCC46U5mO-rz3884D5svbaX33imr8B0iUuRmgFdvljKyBlSbWlaWUyYm4pEOhmxUWqN60q_mtJM3c2VHoWi_CEDDhnmlPH76AC1RieK_BkDfjHg6TJ16r8Gz9kN8HGVurj1_uXny4snf85TfwE1",
#     "sitedomain": "sso.godaddy.com",
#     "pagetitle": "GoDaddy DE Seite nicht gefunden (Fehler 404) GoDaddy DE",
#     "firstseentime": "2022-02-20T05:19:09Z",
#     "firstseencode": "403",
#     "ipaddress": "23.45.102.212",
#     "asn": "16625",
#     "asndesc": "AKAMAI-AS, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.bypassesso365login.psern4l.cc/",
#     "sitedomain": "www.bypassesso365login.psern4l.cc",
#     "pagetitle": null,
#     "firstseentime": "2022-02-19T13:35:19Z",
#     "firstseencode": "aborted",
#     "ipaddress": "205.185.115.92",
#     "asn": "53667",
#     "asndesc": "PONYNET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.bypassesso365login.psern4l.cc",
#     "sitedomain": "www.bypassesso365login.psern4l.cc\n",
#     "pagetitle": null,
#     "firstseentime": "2022-02-19T13:28:29Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://login.authrize-o365login.fpsuem9.cc",
#     "sitedomain": "login.authrize-o365login.fpsuem9.cc",
#     "pagetitle": null,
#     "firstseentime": "2022-02-19T11:08:36Z",
#     "firstseencode": "500",
#     "ipaddress": "209.141.34.163",
#     "asn": "53667",
#     "asndesc": "PONYNET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://login.bypassesso365login.psern4l.cc",
#     "sitedomain": "login.bypassesso365login.psern4l.cc",
#     "pagetitle": null,
#     "firstseentime": "2022-02-19T11:08:23Z",
#     "firstseencode": "500",
#     "ipaddress": "205.185.115.92",
#     "asn": "53667",
#     "asndesc": "PONYNET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.o365offserv.gmazilnconet.com",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-19T10:19:26Z",
#     "firstseencode": "aborted",
#     "ipaddress": "142.250.185.142",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.authrize-o365login.fpsuem9.cc/",
#     "sitedomain": "www.authrize-o365login.fpsuem9.cc",
#     "pagetitle": null,
#     "firstseentime": "2022-02-19T01:03:38Z",
#     "firstseencode": "aborted",
#     "ipaddress": "209.141.34.163",
#     "asn": "53667",
#     "asndesc": "PONYNET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://login.authrizeo365login.rgade4i.observer",
#     "sitedomain": "login.authrizeo365login.rgade4i.observer",
#     "pagetitle": null,
#     "firstseentime": "2022-02-18T11:08:09Z",
#     "firstseencode": "500",
#     "ipaddress": "185.184.223.207",
#     "asn": "4785",
#     "asndesc": "XTOM-AS-JP xTom, JP",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.authrizeo365login.rgade4i.observer",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-17T22:35:02Z",
#     "firstseencode": "aborted",
#     "ipaddress": "172.217.23.110",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.authrizeo365login.rgade4i.observer",
#     "sitedomain": "www.youtube.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-17T22:34:25Z",
#     "firstseencode": "200",
#     "ipaddress": "142.250.186.142",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3Da3ee3083-225c-201e-6c10-1c20e0341ace%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637807284087213629.d62a8fe1-9cf6-4407-b3af-a548c25d7ae8%26state%3DfU_RToMwAAT9lu0NB6VQ9kBMscUwhwTSONe3AsUMQeJAivtP_8fOD_CSu-Qudw9nGoZxq3mjadpaDOS7KLARCKAdIOC4Ptje1T4QQSMda1s1vgWhjazSFY0lPBhUwKuRkIGptz_mZlBic59Msk9IiHH6jkl-4W3cp_2u3TPqpoxOz6S6HE-2l7FCZ1HLCe8yRiFvc3XMo0f8h4cBP5H0o_QU8yhHtCyW1xcVqWgF4gNU5eIdzkzsZ9onOonlRPWIfuKrw_i_VlrzbPet2yuXrOUyj1_nLnTW80mqfqhlFxZS1KkcR_Emr1d-AQ%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-17T21:09:22Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.2",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://login.o365login.villanovauni.cc",
#     "sitedomain": "login.o365login.villanovauni.cc",
#     "pagetitle": null,
#     "firstseentime": "2022-02-17T11:08:35Z",
#     "firstseencode": "200",
#     "ipaddress": "209.141.50.206",
#     "asn": "53667",
#     "asndesc": "PONYNET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D0b3b590a-9e64-d8af-750f-10ec9d74feb0%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637806858161869750.2d87986d-9c82-4f89-8380-8607faa37140%26state%3DfU9dT4MwAAT9Ldsbrny15YGYYouiqwRCnOtbGZ0ZgsQxKe5_-n_s_AFecpfc5e7hbMuyrg2vDG1gxELQRxhAHGIXuhhGKAQ3XoNRhGHjRDvsOcEeRw72MXAwBGgvpY_cANhm-2OvBi1Xt9lJ9RmNCeHvhBZn0aY97x_bdcV8XrHTM92dtwcQ5lVpsqQVVHR5xQLRFnpbJPfkD3cDeaL8ow51FTKBWF3Ory860cnCSzeBrudwc6zkemJ9ZpJUnZgZsU9ycYT81-KNyB--TXvh06Wap_Hr2MXucjoo3Q-N6uJSyYarcZRv6nLlFw%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-17T09:41:31Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.4",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations for /url test
# We got 50 results for our simple test. Was that because we are limited to 50 results? Or because that was how many there were? We will need to test some more to find out.
#
# The format of results is shown below and is the same format as other results we have seen. So it seems there is one format for all search results. All API endpoints produce the same record type.
#
# `
# {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D14e1a2bb-f887-0e4f-7951-b9009dea7b6f%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637816299138232509.6d434649-a21f-4718-97dc-0f1c74fe5bdf%26state%3DfU9dT4MwAAT9LdsbjkIL9IGYYotBVxdI4xxvfBQzBhIHUrL_uf9j5w_wkrvkLncPZxqGca95p2naWgzfc_0AeA7GwA0c10E2fvBq6EIPYqtwQGNBHwQW9uvKshtQ-bCRqKwbU2-v5mZQxeYxmWSf0JAQfiI0veRt3PP-pd0K5nLBpjdaXQ5HG-1EprOozWne7QSDeZuqQxo9kz88DeSV8q8SKYFY7rMyWz7eVaSilRPvoSoXtD-LYjuzPtFJLCemR-yb3Bwh_7X4CZUR1u2VS9dymcefcxeC9XyUqh9q2YWZLGoux7H4lLcrvw%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-28T07:45:06Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.132",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
# `
#
# An important question is, "What do these records reprensent?" What is the taxonomy?
#
# Take a look at the record above. Is the siteurl the URL for a phishing site? Or for a URL that redirects to a phishing site? It looks like it redirects to an autodesk.com URL.
#
# When I am investigating a phish, I often when to distinguish the URL delivered to the victim (via email for example), all of the domains that redirect, as well as the final "landing page" URL the victim is redirected to. In addition to that, some of these pages are just MITM proxies, and whenever possible it is nice to know the site they are proxying for.
