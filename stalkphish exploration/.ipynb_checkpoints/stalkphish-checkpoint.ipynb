# %% [markdown]
# # Exploring the StalkPhish.io REST API
# StalkPhish.io is a hosted service based on the open-source software version of StalkPhish. StalkPhish is handy for gathering information about phishing sites, capturing copies of the phish kits used etc. If you are doing research on phish kits, or performing incident response for phishing incidents, or gathering threat intelligence on phishing campaigns or infrastrcuture, StalkPhish is really nice.
#
# The hosted version has an API that you can use to search for information they gather. If you have you own instance of StalkPhish you can have it gather info on targets of your choice. But with StalkPhish.io you can search for info about a large existing base of information.
#
# ## API Documentation
# I used the following three sources to understand the API:
# - The FAQ: https://www.stalkphish.io/faq/
# - The API documentation: https://www.stalkphish.io/documentation/api/
# - This Blog Post: https://stalkphish.com/2021/06/30/howto-stalkphish-io/
#
# ## Purpose of this Notebook
# This notebook contains my experiments exploring the StalkPhish.io API and tests of how the API works. I have some general tests to ensure that my python works correctly with the API, but I also have experiements to see what kind of data is available.

# %% [markdown]
# # Requirements
# I will require only a few python libraries for our experiments.
#
# - "os" is used to get environment variables
# - "time" is used for time.sleep() so we can wait between multiple API calls
# - "getpass" is used to allow the user to securely enter their API token
# - "json" to format JSON output nicely.
# - "requests" to handled HTTP GET requests and responses

# %%
import os
import time
import getpass
import json
import requests

# %% [markdown]
# # Define the StalkPhish.io API v1 Endpoints
# Not all of the endpoints are curreently usable. This is based on the API documentation found here:
# https://www.stalkphish.io/documentation/api/
#
# According to this blog we have access to the following endpoints on the free plan.
#     https://stalkphish.com/2021/06/30/howto-stalkphish-io/
#
#     /api/v1/me : Return informations about account linked to API key.
#     /api/v1/last : Return n last results, with n depending on your subscription.
#     /api/v1/search/url : Return results of string search appearing in a URL
#     /api/v1/search/title : Return results of string search appearing in a website title.
#     /api/v1/search/ipv4 : Return results of IPv4 search.

# %%
# Stalkphish API Endpoints for API v1
ep_base_url = 'https://www.stalkphish.io/api/v1'

# me: Return informations about account linked to API key. Limited to 100 request/day, out of profile quota.
ep_me    = f'{ep_base_url}/me'

# last: Return n last results, with n depending on your subscription.
ep_last  = f'{ep_base_url}/last'

# email: Return results of e-mail found in phishing kits.
ep_email = f'{ep_base_url}/search/email' # requires a search string appended to URL

# ipv4 : Return results of IPv4 search.
ep_ipv4  = f'{ep_base_url}/search/ipv4'  # requires a search string appended to URL

# title : Return results of string search appearing in a website title.
ep_title = f'{ep_base_url}/search/title' # requires a search string appended to URL

# url: Return results of string search appearing in a URL.
ep_url   = f'{ep_base_url}/search/url'   # requires a search string appended to URL

# brand: Return results of string search appearing in a brand name.
ep_brand = f'{ep_base_url}/search/brand' # requires a search string appended to URL

# %% [markdown]
# # API Authentication
# The documentation at https://www.stalkphish.io/documentation/api/ seems to contradict the documentation at https://www.stalkphish.io/faq/. Perhaps I misinterpreted or misunderstood the API docs.
#
# I found the instructions in the FAQ work. We need to set the "Authorization" header to include a string that starts with "Token " and ends with our API key.
#
# I have also added a header for a user-agent to help the API operators identify this script should troubleshooting be required. While not required it's a good practice and polite when using a free API.

# %%
# Get the StalkPhish.io API Token from ENV or user input
if 'SP_TOKEN' in os.environ.keys():
    token = os.getenv('SP_TOKEN')
else:
    token = getpass.getpass('Enter your stalkphish.io Token:')

# When we send the token in the authorization header, we need to add the string "Token" in front.
authorization = f'Token {token}'

# It is polite to set a meaningful user-agent. If our script causes problems for the API this
# helps the operators troubleshoot so they can contact us about problems.
# In general RFC7231 says user-agent strings should follow this format:
#   User-Agent: <product> / <product-version> (<comment>)
user_agent = 'cyberlibrarian-stalkphish-test/1.0 (michael@cyberlibrarian.ca)'

# We need these headers at minimum, Authorization is most important
headers = {
    'Content-Type': "application/json",
    'Authorization': authorization,
    'Accept': '*/*',
    'User-Agent': user_agent
    }
# Out:
# Enter your stalkphish.io Token:········

# %% [markdown]
# # Tests of the API

# %% [markdown]
# ## /api/v1/me test
# This endpoint will fetch information about our account. It makes a good test to see if we authenticated correctly to the API. It is limited to 100 per day, so limit the number of times you test with it.

# %%
# Search for my account info
# We have already set the authentication information in our headers at the beginning
try:
    response = requests.request("GET", ep_me, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %% [markdown]
# ### Information about our Account

# %%
try:
    response_json = response.json() # raises an error if response is not JSON
except Exception as e:
    print(f'Err: {e}')

# Careful! The response JSON contains our API key which we DON'T want saved in the printed output.
response_json[0]['api_key'] = 'XXXXXXXXXXXXXXXXXXXXXXXXXX'

# %%
# print the response code we received
print(f'Response Code: {response.status_code}')
# Out:
# Response Code: 200

# %%
# print the response we got from the /me endpoint
print(json.dumps(response_json, indent=2))
# Out:
# [
#   {
#     "username": "cyberlibrarian",
#     "email": "michael@cyberlibrarian.ca",
#     "api_key": "XXXXXXXXXXXXXXXXXXXXXXXXXX",
#     "subscribed_plan": "Free"
#   }
# ]

# %%
# print the headers from the response
print("\n".join([f'{header}: {response.headers[header]}' for header in response.headers]))
# Out:
# Server: nginx
# Date: Tue, 01 Mar 2022 17:09:20 GMT
# Content-Type: application/json
# Content-Length: 145
# Connection: keep-alive
# Allow: GET, HEAD, OPTIONS
# X-Frame-Options: DENY, SAMEORIGIN
# X-Content-Type-Options: nosniff, nosniff
# Referrer-Policy: same-origin, strict-origin-when-cross-origin
# Cross-Origin-Opener-Policy: same-origin
# Strict-Transport-Security: max-age=15768000
# X-Xss-Protection: 1; mode=block
# Feature-policy: accelerometer 'none'; camera 'none'; geolocation 'none'; gyroscope 'none'; magnetometer 'none'; microphone 'none'; payment 'none'; usb 'none'
# Content-Security-Policy: default-src 'self' http: https: data: blob: 'unsafe-inline'

# %% [markdown]
# ### Observations for /me test
# It would be nice if the JSON returned some information about which tier of service the account is in, or how many API lookups are left for the day. More status information would be very helpful.
#
# I expect the "Content-Type" header to always be "application/json", but when there are errors does it sometimes return plain text or HTML?
#
# The Response code should be explored. The API documentation says there are three values: 200, 401, 429.

# %% [markdown]
# ## /api/v1/last test
# The documentation says this returns the last "n" results with "n" depending on your subscription.
#
# It is unclear what this means form the doucumentation. What results? Whose results? Let's test it and find out.
#
# Conclusion: This appears to be system wide: The number of records addedto stalkphish.io. Interesting.

# %%
try:
    response = requests.request("GET", ep_last, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %% [markdown]
# ### The last queries you made with this account

# %%
print(f'Number of results fetched: {len(response.json())}')
# Out:
# Number of results fetched: 30

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# [
#   {
#     "siteurl": "https://drive.google.com/file/d/1lb3dFwmcHaLHVZvxVdyNaV8galnF_Ihk/view%3Fusp%3Ddrive_open",
#     "sitedomain": "drive.google.com",
#     "pagetitle": "Page Not Found",
#     "firstseentime": "2022-03-01T16:48:46Z",
#     "firstseencode": "404",
#     "ipaddress": "142.250.185.78",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.equifax.com/personal/education/credit-cards/when-late-credit-card-payments-post/",
#     "sitedomain": "www.equifax.com",
#     "pagetitle": "When Late Payments Show on Credit Reports | Equifax",
#     "firstseentime": "2022-03-01T16:45:01Z",
#     "firstseencode": "aborted",
#     "ipaddress": "107.162.153.204",
#     "asn": "55002",
#     "asndesc": "DEFENSE-NET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.experian.com/blogs/ask-experian/credit-education/score-basics/what-is-a-good-credit-score/",
#     "sitedomain": "www.experian.com",
#     "pagetitle": "What Is a Good Credit Score? - Experian",
#     "firstseentime": "2022-03-01T16:44:10Z",
#     "firstseencode": "200",
#     "ipaddress": "45.60.124.189",
#     "asn": "19551",
#     "asndesc": "INCAPSULA, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://billing-report.com/login.php%3Fcmd%3Dlogin_submit%26id%3D",
#     "sitedomain": "billing-report.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:38:17Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.linkedin.com/uas/login%3Fsession_redirect%3Dhttps%253A%252F%252Fwww.linkedin.com%252FshareArticle%253Furl%253Dhttps%25253A%25252F%25252Fmyemail.constantcontact.com%25252FThe-latest-CPQ---Billing-and-B2B-Commerce-news-for-you-from-PolSource.html%25253Fsoid%25253D1132917062006%252526aid%25253Dmjrq7D8ObQM",
#     "sitedomain": "www.linkedin.com",
#     "pagetitle": "LinkedIn",
#     "firstseentime": "2022-03-01T16:37:54Z",
#     "firstseencode": "404",
#     "ipaddress": "13.107.43.14",
#     "asn": "8068",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://pubco--c.documentforce.com/sfc/dist/version/renditionDownload%3Frendition%3DORIGINAL_Png%26versionId%3D0683t0000089I54%26operationContext%3DDELIVERY%26contentId%3D05T3t00000TVPRf%26page%3D0%26d%3D/a/3t000000VGWs/6.RFNyHO8F_3.eHu3uCRV_uhoWkfmIwjUCiVH.D0vMg%26oid%3D00D3t000001yXGn%26dpt%3Dnull%26viewId%5D",
#     "sitedomain": "pubco--c.documentforce.com",
#     "pagetitle": "Unable to Process Request",
#     "firstseentime": "2022-03-01T16:36:51Z",
#     "firstseencode": "200",
#     "ipaddress": "13.110.43.50",
#     "asn": "14340",
#     "asndesc": "SALESFORCE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://pubco--c.documentforce.com/sfc/dist/version/renditionDownload%3Frendition%3DORIGINAL_Png%26versionId%3D0683t0000089I54%26operationContext%3DDELIVERY%26contentId%3D05T3t00000TVPRf%26page%3D0%26d%3D/a/3t000000VGWs/6.RFNyHO8F_3.eHu3uCRV_uhoWkfmIwjUCiVH.D0vMg%26oid%3D00D3t000001yXGn%26dpt%3Dnull%26viewId",
#     "sitedomain": "pubco--c.documentforce.com",
#     "pagetitle": "Unable to Process Request",
#     "firstseentime": "2022-03-01T16:34:50Z",
#     "firstseencode": "200",
#     "ipaddress": "13.110.67.50",
#     "asn": "14340",
#     "asndesc": "SALESFORCE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://colindolman01.xyz",
#     "sitedomain": "colindolman01.xyz",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:32:23Z",
#     "firstseencode": "aborted",
#     "ipaddress": "143.198.41.10",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://microsoftronline.com",
#     "sitedomain": "microsoftronline.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:32:10Z",
#     "firstseencode": "timeout",
#     "ipaddress": "194.58.112.174",
#     "asn": "197695",
#     "asndesc": "AS-REG, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://radiojesusteama.org/lnuo/",
#     "sitedomain": "radiojesusteama.org",
#     "pagetitle": "One moment, please...",
#     "firstseentime": "2022-03-01T16:32:04Z",
#     "firstseencode": "aborted",
#     "ipaddress": "184.171.252.138",
#     "asn": "33182",
#     "asndesc": "DIMENOC, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.jcb.foykvzg.cn/",
#     "sitedomain": "www.jcb.foykvzg.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:31:58Z",
#     "firstseencode": "aborted",
#     "ipaddress": "23.94.98.190",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://auth-slack.com",
#     "sitedomain": "auth-slack.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:31:56Z",
#     "firstseencode": "500",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://localtrack-missed.com/",
#     "sitedomain": "localtrack-missed.com",
#     "pagetitle": "Redelivery | PostOffice",
#     "firstseentime": "2022-03-01T16:30:01Z",
#     "firstseencode": "timeout",
#     "ipaddress": "31.210.20.59",
#     "asn": "211252",
#     "asndesc": "AS_DELIS, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://hsbcainfo.com/",
#     "sitedomain": "hsbcainfo.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:27:57Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazom.co.jp.rtaornl.cn/",
#     "sitedomain": "amazom.co.jp.rtaornl.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:26:08Z",
#     "firstseencode": "aborted",
#     "ipaddress": "107.174.67.44",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.amazdn-bob.shop/",
#     "sitedomain": "www.amazdn-bob.shop",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:26:05Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amuzon.co.ip.xqqfobl.cn/",
#     "sitedomain": "amuzon.co.ip.xqqfobl.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:57Z",
#     "firstseencode": "aborted",
#     "ipaddress": "204.44.99.190",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amuzon.co.ip.xjzmkla.cn/",
#     "sitedomain": "amuzon.co.ip.xjzmkla.cn",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:50Z",
#     "firstseencode": "aborted",
#     "ipaddress": "204.44.99.190",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.depthfi.com/",
#     "sitedomain": "amazon.depthfi.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:44Z",
#     "firstseencode": "aborted",
#     "ipaddress": "45.207.38.107",
#     "asn": "133199",
#     "asndesc": "SONDERCLOUDLIMITED-AS-AP SonderCloud Limited, HK",
#     "asnreg": "afrinic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.gomeioh.com/",
#     "sitedomain": "amazon.gomeioh.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:38Z",
#     "firstseencode": "aborted",
#     "ipaddress": "45.207.38.107",
#     "asn": "133199",
#     "asndesc": "SONDERCLOUDLIMITED-AS-AP SonderCloud Limited, HK",
#     "asnreg": "afrinic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.emistra.shop/",
#     "sitedomain": "amazon.emistra.shop",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:32Z",
#     "firstseencode": "aborted",
#     "ipaddress": "45.207.38.107",
#     "asn": "133199",
#     "asndesc": "SONDERCLOUDLIMITED-AS-AP SonderCloud Limited, HK",
#     "asnreg": "afrinic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.adad-wdad.shop/",
#     "sitedomain": "amazon.adad-wdad.shop",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:31Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.minkow.shop/",
#     "sitedomain": "amazon.minkow.shop",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:20Z",
#     "firstseencode": "aborted",
#     "ipaddress": "45.207.38.107",
#     "asn": "133199",
#     "asndesc": "SONDERCLOUDLIMITED-AS-AP SonderCloud Limited, HK",
#     "asnreg": "afrinic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.armazon-co-jp-3-secv.u3iu3p.cn/",
#     "sitedomain": "www.armazon-co-jp-3-secv.u3iu3p.cn",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2022-03-01T16:25:14Z",
#     "firstseencode": "aborted",
#     "ipaddress": "167.160.188.175",
#     "asn": "8100",
#     "asndesc": "ASN-QUADRANET-GLOBAL, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.co.jp.vips7.sonuza.xyz/",
#     "sitedomain": "amazon.co.jp.vips7.sonuza.xyz",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:07Z",
#     "firstseencode": "aborted",
#     "ipaddress": "198.46.189.134",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://amazon.co.jp.untes.sonuo.xyz/",
#     "sitedomain": "amazon.co.jp.untes.sonuo.xyz",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:25:01Z",
#     "firstseencode": "aborted",
#     "ipaddress": "198.46.189.134",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://colindolman01.xyz",
#     "sitedomain": "colindolman01.xyz",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:20:01Z",
#     "firstseencode": "timeout",
#     "ipaddress": "143.198.41.10",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://b4e921f0.sso-mailsrvr-4344e5teed.pages.dev/support/%3Femailtoken%3Dabuse%40gmail.com%26amp%3Bdomain%3Dgmail.com%23eyJ2ZXJzaW9uIjoiMC4yLjAiLCJjb21wcmVzc2VkIjpmYWxzZSwiYm9keSI6IlxuPCFET0NUWVBFIGh0bWw%2BXG48aGVhZD5cbjxzdHlsZT5cblxuPC9zdHlsZT5cbjxzY3JpcHQgdHlwZT1cInRleHQvamF2YXNjcmlwdFwiPlxuXG48L3NjcmlwdD5cbjwvaGVhZD5cbjxib2R5PlxuPCFET0NUWVBFIGh0bWw%...%%...%2BPC9zY3JpcHQ%2BXG4gICAgPHNjcmlwdCBub25jZT1cIlwiIHNyYz1cIi4vU2lnbiBJbl9maWxlcy9zZW50cnkuanMuZG93bmxvYWRcIiBjcm9zc29yaWdpbj1cImFub255bW91c1wiPjwvc2NyaXB0PlxuICAgIDxzY3JpcHQgbm9uY2U9XCJcIiB0eXBlPVwidGV4dC9qYXZhc2NyaXB0XCI%...%2BPC9zY3JpcHQ%%2BXG4gICA8c3R5bGUgdHlwZT1cInRleHQvY3NzXCI%...",
#     "sitedomain": "b4e921f0.sso-mailsrvr-4344e5teed.pages.dev",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-03-01T16:09:34Z",
#     "firstseencode": "aborted",
#     "ipaddress": "172.66.44.238",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://u18741649.ct.sendgrid.net/ls/click%3Fupn%3D6Ai2rV-2BpihcqvBT-2BRKf5xOlW9Fon-2FznvJFMXj2N1oiRSBMjwdT4or9iMZAvRJCYOazQHDdFy0Z35r5DpqvLwY-2FC6YGc-2BflwJX5sPGZGPO2EXlI6WM6OTuPNUkhPXu7avwoQ-2Bq5VASisxsMR4ORiGRRUSd-2Fnf0Vux7iW76cMWpfI-3DnCUx_lQ-2FVWiMNdEN5cPeVRjPVkH8J8xD5qm3pXeFgj33tX3ydcUo3bDD0QeSV9iTQ2wITSMxp-2FB5uYaqoQUGuD67YC8dLH-2B7z-2BDVIGBaqX1Sah-2F3P9N3g126bYAZg1x-2F8kS0YbtnVQwDrjhMpupYU5Ohb5owWjH6olxNEjcQYbZz6ohttcJs-2F7Qxjtq3-2Bt4tiC5SNUSp-2BJA7JgmNQdWYtXzf-2BPixwbHuOD4uJgY8i9uz4utL5-2BUshFanlM3HStaY39CxTaEJcez7JM1Eo-2Fe5DxJHh8Mhn3HTP-2B-2BP0mjK8Lq5yoWa5WXEMCa2fHZ0nvIo1REvUPFwxnxTfA-2FwgZEqindO-2FcFku2SN-2FALvAFtQHdgUxj9LPGGmBvNNbJFrcx5JIa6u5uNLp0driydqBC8O4n0A-2B6uITwrj0X2zpdbqCgUC5dWxd5VeKDcP-2Fvl2u2tJb0xsU69Auas2tvJ4bZIEgxIUjdh9aOpWQBhngvS1E0c1LC6Uaxjd4GFfC4DH851RL-2BuPIo0gjiNpXahaI8JXcSlMgIgW46irysNxD-2BnIYZh9jm0mEzPQQQiweDv-2BJVzqqqUSu8fNud9dYrUnXcs8sxY7oG-2Bslbstds1BxIUivJZ0eu4edzUZmjvl8pjq0WE2wxuS93Nsusns2B3b5n4QJjX04nXkWOOwmyhfH39HtAQxNiwJsWfnhAmhfaKr6qo-2Bp8-2BfgIz1IfXkteLKeyNNUrTrkK7Z8FfuBJ4r5-2BFcOMacqFoo8-2Bb6d4b48t0MGpgVFhwQ7PSsgLCPF9wcncrnDwycsofw-2FgyIEb7qAUMWUyZvpwPyEILlDWSm1pv3opdA6FZHx83ZSNDpbflScEyYVkoEbUgl8xszpY7Q1SIgj9xkCmVia7A3CxYdyihv-2Fpa9Vpj7Cesj-2F35Jmrrd4zMnyCYjpt-2BeNbqmrwxSbY3icokbJEDfiEA-2FqXgOSN9grE1L9mFb72CLBWUKd2mdmcHespwMWpVcgj0gOH6f1jYvH3cqF0dqPlZlBLb6r9DPjSkeQccxT6-2BFvdswyfkmZq7mmPyMQV2kjKReVxDSuOxw3oxiG2W4ozu9msj3IaGyavPRFYxqkGWzwSeD6hF8QjL-2BTr5FPTk0BS9SbkjUKOYasvTElfxOYK-2BTU578tms3SQ8-2F9cPAmM-2FUjdn3W-2FXvwLpPpj-2F-2Bl-2FOasYxEsTy0MQ4NpjSJ-2FS3j3yEgCc3kmATCCiu2kEiVcgyvvuIf4slMLmc5uA4o0fLA3vphFziwm-2BffhMZAxBgP03q0u7V9W2Io-2FuQEwKGBbv6Z0Y6Dgqd8WlsA-2BUnuxqyeyz-2B8nTzZet44xx1fpdJQ2yLqZAebbVZnjt0LOQailakAxNfuMQc-2BO9ketPBtn1vc2l-2FiXnVSOiOXbxdTGWoT2-2F1fQzABqcE1DusfRoLmOh0EVOjhpEa-2FFWzs0JfRZ5t1gSlYvGD6nSLnNQban525ZZjia-2FXfMPrHjNTD8a1cKPAfTZ9GrWseImbTD4PFUB2axIkEBs2MeTOIBzWJKpX1W6QIYOLRe9Ay-2FvOdMWzEcZ22nSmToUu0bmXOXHIzFotzEf7yTNDb7BqAoFbo3OWG0-2B346gZduoOITY3GeY4LbqF7HpkqwFnUhL0Cvj-2Bb3NEF-2FiNbe4z2dbSkNSUxvj-2BBreSPuN094UcWWG96rANQcwUzcjRVHn-2FBu--2Fm15LHP9ExW3yNMTtskC2Vpt9hfwS0TuQHrP8TYJrigjt7niUpcBoQtgbosq2N0mQVyUOjOqVNyT3ebovOV0rp3lIfHnJaJovXIzFK-2BLISHFVtukwK24R-2FMKId1ume3W5gdKK8YBNcItCMn6z4p-2FC6i1-2BMx-2FG-2BP9sbziT6C8AQOyF6fk8mMoEnkhHKQAKIGfWtrEdC2upau-2BL6IYaOwSjICbxGwhaeuPVWY63CmmJPGeccZDToKHAc3kk3A-2BVvs4uhmjEF5e1kYsUY6-2F6sreMQTtaAX08wl-2BhCynNihmivtKy4Y00dXZjjxvSs6m9bY2j-2FJ2aMgTGqVU3wJWm4Pw9BeHPxR1vXvLG2OEHMbiseePL5UAzTqRYxk8eDz1wkxKqctCKkw3HYlgXPaDw8JPABhZYTVJzoJSPcBpxyAwq0CdxBWjm1WtEzMEKG2j6UD2pFXQP4bk05K7BRb0e9ZGa7DwQKUwEn8SNh8gSDKrEtN6qUoQdyxgo8kiZR7IrnQM4rByrBZ90vINHfMFOTucxVb-2FcDvAj8YgVoavoS-2FGPXC1I6cmnGk8hecik97SD0ENvkRHw0SeVBH-2F1VcVNjQjceZpYfUbuv7bqxeq6YeGjchfgER8NCV8-2F7OLOt4IAVMysVy8qE-2FGYBA17Bo4k3nhzXR0Whw4JxsIcm5ZA8-2FjD6mymHu9fe4CPagBJpu4NvwVEncVcGX3IM3nndl39tsC739bV-2B42GMSPg-2FLPYb8JYhlNxcWh1J-2BmVZg9q7pWm4vAEjRDS5RoqYU-2B52deyWPMEckChNcdcvkMkcRMyqz98nThXQ5RudQuFKVlnYCaQDEFBlMA3KzT7kF5iCIp4cFyZvGSUme059STNZN-2FzPeP-2Brp6s2pBlJfmUIoYYkv7jHHRp7wrbrEpR1iufUjKC4ItKbdD3T5KzTZDIql8tKxb8d5U0D93Lu-2BUDespauoJVgnTj7xcOqAhhskAciWY2QfSHQh-2Bc0KmC75XqfsWfzLEJ7Bv6pVdxQWnEhnl67eHi1m4Srg-2F-2FUzDV5Ae5VRl1Rvs7yTbG89WHwQxW2VvpoT8iN7MYRzv0bRHtgOBm8W1OM-2FRs6qBmBbvM1oPciiLGVWSaTvmxJHvT4pZ4sdfE1sxfPjYnhsRCKt-2BcOmpHoHuON-2BSRweZkiCVefKJoFur3bYvgqaVmxu-2BdHr8dgNDo14BYTH-2FZ4ujUagsAm5a4cjwHwpsDtB0hHVjVW-2BPIdu7AlilcPL0VMGLnaYw-2FWE14D-2BThgY5uQ2tud4W7GrhUNBmefIOM-2BHTf32I2kECgaByQm5MIqBWHyPI2rb6viBi7pow5jx3ec25M3LbF6qbPBsv8cWY4m6CzKeqYp7vRZJL9-2Bt6rrj1qUX0XVUcwNlnwTTd-2B4bbwSj5C0iVX0vhmhG9GEDsif70E1YbEK5xCx5wyDx6tshPMU9CcMArXg0BWLq2O1VjCwFdUCidtiDDJjQ6LUbFJ2gc1XwaTuESG-2FodFG-2Ftl1W4pt9Lu2qnlW-2BEFwvwMHHNJ-2FkZ7vZX91qIfaX1zUTxM0AWIFzvPTPVW4WxTlfP1K8Jqp2niEeSOxnF-2FOkHeQpL-2BE2xutwY7N ...
#     "sitedomain": "u18741649.ct.sendgrid.net",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:09:14Z",
#     "firstseencode": "aborted",
#     "ipaddress": "167.89.123.122",
#     "asn": "11377",
#     "asndesc": "SENDGRID, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://u18741649.ct.sendgrid.net/ls/click%3Fupn%3D6Ai2rV-2BpihcqvBT-2BRKf5xOlW9Fon-2FznvJFMXj2N1oiRSBMjwdT4or9iMZAvRJCYOazQHDdFy0Z35r5DpqvLwY-2Fkj6GCOD-2BpYMLFjI61ovfBludtA5zpVyG58Fvlbadb-2BpM9RkIH6l0UUz7v7QEAlOMJ6wcU-2B941T550txO5Uw20-3DFsuX_lQ-2FVWiMNdEN5cPeVRjPVkH8J8xD5qm3pXeFgj33tX3ydcUo3bDD0QeSV9iTQ2wITSMxp-2FB5uYaqoQUGuD67YC8dLH-2B7z-2BDVIGBaqX1Sah-2F3P9N3g126bYAZg1x-2F8kS0Y98toxr2FnQLstkujplZZzf6PkAuiMT1m1Z2TUN-2BWP6wcnr5zCcpZI4lwZkcaJ0Wvd6GUzMLxbEtS2DYQGGWYC2LsU-2FD7T6nljf-2FuE7OzIiLINVESJcpPd3atjBRF4z6OEAxtpvnH6-2F2WaqwNB5B6KkoYZxOHfHGQDedrn1l8S5c1nAhjZBTmOzrkYKhtF7MgY-2F-2BSLKAeFcL7fFgtaKwB1gJZpxm8hfhi15vHmLp2ttkGxW7jGZHjoWXyfYXsmaD22cdBDfP71VV2buR6s6XE-2FJCaNBWDcBl-2BjHG-2FD6ghDFfGdTsDJg2lVFgv-2FXzoGsFTISh8DqdCj6-2FzDSNmOqLIdeMO9KN6lniMIeDgX7F0qACzzYceKmJQ6puDLwJ0t0kvCmuR-2BIsAW0qIMHPVK6fSxiBuaMVxkyWX7XWMhMCURQiW7VOHkZW-2Flcnm2U65QO0ycqFySotkybkPWJKiTq057sAoR-2F-2B3yrF0k7pRDYYNdn-2FQZxunE-2FYKhBcRQ23AQi3x-2B80zUl-2BqKoAXiw-2B4SLF1XxSBurpLA0BJft4jSRFtRG48E4qiBuBEMP6USTsDzyOis6yi0oXrli6oS5IlZOU-2Fo4Gi7oyXDAyLTIhlT-2BPzFMHDrkW80i8jw4wGM9KOkXJU13az9NjuIPdtaU1v10z6TWuFUVIs-2BWm1yGsQgB25ibTvaKno7f-2BMtx-2BIBTvNT-2FPJOgjwrXyDclgbUjO6CJmzJBG9iE57mc9EltOO471riNA-2Fkb-2FnrM4ZKNrIzvMDL58N1caiDhImR6RnCAq-2BJvZnFqNjB7vvThiLSGDKZromFGnYY8NBjcuY23yDaFeIeHnk5x-2Fx3bmMtVQRULZ7KJ8S2RqOaXoggDisMo8TN9KwR8Trb1NYQ2LwVFvrZz5W1CKt8VplYdkd2Fsx9oqIn3BR4EJACo0urLKHmvI-2F-2BDORyxnKPKoPqtA6kImOcBtx9lgna3N-2FK6nnCAilhqKLSrMcbBOVGcWF-2FEX5drMM-2BeKEZdBvJfKcD8mPbf5yB5H7UPFUGsEhFXnQWGgehry1WFoXvxoFsDwEX5-2BOS6zQ8-2B9Qd-2FnUHxh9xTaGuqJugPMPBAByRxNQThag5P1c39hRkxV9Uq-2FKIIW-2FZ6UbWIuO3mU5AjuhwqZvsKrs3Hl93-2BfGoZSgEvjDr3amQMNRTLN61u0SZ4Gw4-2BtGGUIg1AtPlYrCidZu5sWAVAzzho6I8ee379tuxXjEZ9Ucl6bSJQWH-2FPToEBcbtUbyvH1aydrV3-2BtWp2RvhLqB1StLhQXvYE2Ctnmmh5zSLVlPJ4PD2KvY4sHn0hGV7tWoMxolobIuDlQZviDBbtQh-2BbdqPNepl9y09y0kB-2BWu4s3PDdPNtJjtQvUcVW6EEepRujFvuzvtLRFSoBTxXtUja4DtsVywCUMgIinGNWadMrEFhlr-2B1yZdVAOnAEXRz61ys4djBKRXhAyQyaSr7HVBLcVmaz139ByZJGxc0aaqUll1Ns5ue5haxrf6tNr2W3H8czGBEy-2FsctxrR-2FGrbb1lWL-2B-2Fh6eMChz0GIqQSVPhSv4jS2nLK62otpcQbsKF7ExZ3GVxR3oNvKiVWS4nTnet-2FqsPVXrg2Q9GZIa-2FM4Awr2OcepJDf28A-2B3wGxbDaaU6lzcFzQb6JnK-2BBw8dSEdRBj-2Fv3nB3ZjG5EQfb-2Bdww6-2BES5dVFlbZt-2FqZLNudd6-2F6pL6vN6gDAK-2FefnN-2FNYqku-2BcME-2BqZ-2FD2FtWFJkdhCXbvIq-2FyDGYsIYVE7cH5V5lhKnMeeuUoL-2FqNCGJ6dQjm1kBDcSTjhcJd-2Fh3DtsxJsYnpFmkSje9yEqdYX0rdL4BJjwNdUFec0l80a2V7gsdC72By4U-2F9QF82xWI0e57smOyWYg9rZtWEJLWBWJt2K6d0zYnatYOpgdcXw-2Faim7E9gkZo3-2FMK-2F4TfxTytsGrsmomEXEu9XE5HOzSyPn8PRPShYeW7UNty0aFlNAoE21FfIJgJwFRLmKfFzTXBMaQtwTV0EEuw1bwXjI3IYlAnumen0nRZIRByGOamp-2BcRgJoQIUDcQyPinyiqp9j7ha-2BpS8un97KiGkqvjftVOO7UdzR36-2Bn23LqWTtUQF4xwuKnpocobHGQk5Tq9v4r1qDeytfZvWYWV4lwHmV4sRUr7CyuXEWR-2BAWOAj6ZysMISPUOa2vW0ZCX-2BSEVmwqzMJqDPEwTxbKl6u02T2L8HBsMz839iFXGfHy5ujH3duHahqlK2oXajkA59KG-2F4ftrklINKtCOfzHgtmjv6aRFxzoP1YBzAudwlGnITMXCfX8xZxime3lp7CT2IuctA6Z64-2FrQQf3NYFhfEyWv0leJ1ZG40wY3-2BsMLTTNCEQKGhzaYdY6x2u5t0PanDillKAYBJRuFn1AmYyWbHM6OSTggRH5PcLwy7M24g-2B1uQFm4j4EqLNQvsKrbDsH1XUFDmzb811pLQQAwQPRupfMnMu7cClBLIMeJYp2YnmNtaim431PGxMA5pMQoMcMlHBO7pdX51u8WnKb3Q-2FopsVhgwk3r5scWzfwS42kgY35U2aJi247eGkbUluZYwF0v-2BvjD4QcsQtvSblO1KzX5wMV0y18HDyyNcXQ-2BsKjORxArdqnv7PJoCJonEhnexyX-2BvU84FM3pLwJq22snUGlSqn94NHQoiFYuR5-2FE73cSJQH2cglaxr46n-2B00HfJpUl3hWlxEbKuixXcCaJID0AVWq34Qk5KaQrnVsnW3gPo5nKRRUNTln690Kz0NRHILKklkrSm16aIFkWpzr90vgP57IZrIKiS7f3mGTItmIqwjKL1CBYgvjhsG50Y7AitNJS5Ho6DUiS2pvO3suIA0nkHG7f6RMGq8-2Bzqlml4Ghzb4s1TGl0w3Q43h2v-2FCZjh5YzZUJD642dtxwd6-2BF2l3QvAGoL-2F6C6Nsuoc4fLEZjfnqzDC74cACuFv3emhvtXdVhlr-2BJezg3S1aZdUqJlMHtnG0YfOLbL8w4TL43uxqPnJVmxby-2F7TvFKxuRAiwsPV1XzgI1AGB2UQ45QP8VgDJs5-2B7atzER32jKmIIOoNd6PYzZScjlYpCL2re5CuNXk-2BO-2B9hAzcezr6ECIe3qZCupekFsrotiQemB-2FWwmYdxI72QUe5i-2BT-2Fq-2FqOdOOR3t8t0LqhqGfxXdT0VaB196Zn7tIU2MdaqHoNpee3Itwv2A2gOFIsrn1TWqyQqnpotjXLrgjeGxe2OBOsXLefl8qHeGUAwDRrIGKeNut1mgNFMMh67dkYtq4Gh-2BhsDtxkljKRNOPfWPvbp9kwK4N-2FGrDXR2-2FylfLt4jFf6BDAqwLPJEdexHhRH0jrtuLfg-2FwjP-2Fc0tEAJSPjj1hZAmJdVX1FLTLBdiLSgtndpeym9Eammx2QDX9vvy1BN6soN8GmNnQ4Btk4yb1WBeluBjSVc ...
#     "sitedomain": "u18741649.ct.sendgrid.net",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T16:09:07Z",
#     "firstseencode": "404",
#     "ipaddress": "167.89.118.28",
#     "asn": "11377",
#     "asndesc": "SENDGRID, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations on /last test
# The documentation says this endpoint returns the last "n" results for your account's access level. Apparently "30" is the limit for the free account. n=30
#
# Generally, the API results seem to be in this format. Will all endpoints produce this same type of record or will more context be available?
#
# `
#   {
#     "siteurl": "http://openseca.com",
#     "sitedomain": "openseca.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:18Z",
#     "firstseencode": "timeout",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
# `

# %% [markdown]
# Here is an example of a record with extracte emails. I have not seem many of those. What are they extracted from? Was the phish kit captured and included those emails? Where these the emails used to send this phishing URL? Were these victims?
#
# I probably need to read the StalkPhish source code to figure this out.
#
# `
# {
#     "siteurl": "https://skart.co.in/admin/webmail.cpanel.net/user/cp.user.sign_in/auth/cpanel_mailbox/index.htm",
#     "sitedomain": "skart.co.in",
#     "pagetitle": "Webmail Login",
#     "firstseentime": "2021-12-16T18:33:24Z",
#     "firstseencode": "200",
#     "ipaddress": "43.225.53.210",
#     "asn": "394695",
#     "asndesc": "PUBLIC-DOMAIN-REGISTRY, US",
#     "asnreg": "apnic",
#     "extracted_emails": "pentestmonkey@pentestmonkey.net, openfoxxthemes@gmail.com, check@isnotspam.com, leafot@gmail.com, anthon.pang@gmail.com, traveltino@gmail.com, oyejorge@gmail.com, nicolas.francois@frog-labs.com, Contact@company.com, email@storeaddress.com, info@OpenCartArab.com, florinpatan@gmail.com, fabien@symfony.com, andrew@noop.lv, arnaud.lb@gmail.com, martin.hason@gmail.com, drak@zikula.org, chabotc@google.com, slangley@google.com, beaton@google.com, jon.wayne.parrott@gmail.com, someuser@example.com, chirags@google.com, elsigh@google.com, openfoxin@gmail.com, user@example.com, iam.asm89@gmail.com, stloyd@gmail.com, fran6co@gmail.com, zoujingli@qq.com, BackEndTea@gmail.com, p@tchwork.com, a.aitboudad@gmail.com, kontakt@beberlei.de, michelsalib@hotmail.com, jeanfrancois.simon@sensiolabs.com, contact@jfsimon.fr, michael.lee@zerustech.com, marcosdsanchez@gmail.com, bschussek@gmail.com, clemens@build2be.nl, gtelegin@gmail.com, umpirsky@gmail.com, benjamin.dulau@gmail.com, daniel@danielholmes.org, manu@sprain.ch, michael.vhirsch@gmail.com, miha.vrhovnik@pagein.si, colinodell@gmail.com, thewholelifetolearn@gmail.com, t.nagel@infinite.net.au, florian@eckerstorfer.org, aj@garcialagar.es, bschussek@symfony.com, example@example.co.uk, fabien_potencier@example.fr, foo@example.com, foo@bar.fr, password@symfony.com, pass.word@symfony.com, user-name@symfony.com, error@example.com, florian@voutzinos.com, mallluhuct@gmail.com, naderman@naderman.de, j.boggiano@seld.be, hallsten@me.com, support@divido.com, smith@example.com, mike.jones@example.com, old.email@example.com, new.email@example.com, joe.martin@example.com, timmy@example.com, jane.doe@example.com, joe@bloggs.com, billgates@outlook.com, john.doe@example.com, check@this.com, dan@example.com, name@email.com, payer@example.com, payee@example.com, sandworm@example.com, john@smith.com"
#   },
# `

# %% [markdown]
# ## /api/v1/search/email/ test
# This endpoint will search for e-mails found in phishing kits. It is unclear if this means emails referenced in the phishkit code (e.g. emails used for collection of phished credentials) or if it means emails found in victim dumps in captured phishkits. Or perhaps it refers to emails referenced in phishing URLs (some phishing URLs contain the victims email address)

# %% [markdown]
# In our test we are going to search for a list of email address. These fall into several categories:
# - Addresses that have sent phishing links in the past (compromised or attacker emails)
# - Addresses that have been observed in phishing links (known victim emails)
# - Addresses that have received phishing emails (but not mentioned in actual phishing URLs)
# - Addresses that have send maldocs (compromised or attacker emails)
# - Addresses that have send test emails (during preparation of new gmail.com accounts)

# %% [markdown]
# ### Test 1: with 1 emails: one expected known to send phish, one known safe
# Let's test this endpoint with one email that should not be found at all ("michael@cyberlibrarian.ca") and one that definately should be found (from previous threat intel).

# %%
# Test emails
emails = [
    'michael@cyberlibrarian.ca',
    'thamaraiselvan.m@ionexchange.co.in'
]

# Make a separate query for each email. 
responses = []
for email in emails:
    url = f'{ep_email}/{email}'
    try:
        response = requests.request("GET", url, headers=headers)
        responses.append(response)
        time.sleep(1) # be polite and wait between each API call. This is a free API.
    except Exception as e:
        print(f'Err: {e}')

# %%
print(f'Number of responses: {len(responses)}')
# Out:
# Number of responses: 2

# %%
for response in responses:
    print(f'Respnse Status: {response.status_code}, {response.json()}')
# Out:
# Respnse Status: 401, {'error': "You don't have access to this search option with you profile"}
# Respnse Status: 401, {'error': "You don't have access to this search option with you profile"}

# %% [markdown]
# ### Observations on /email test
# I guess this does not work for the free API. "You don't have access to this search option with you profile"
#
# Initially we sent 14 requests, and ended up throttled after a few attempts to troubleshoot. The throttling was inconsistent. If we made repeated attempts it would report the number of seconds until throttle was lifted but it was different each time. Perhaps there are multiple backends each with a different count?
#
#     response.status_code=429 means we were throttled.
#     response.status_code=401 means we do not have access with this profile.
#
# Response "401" can also mean our authentication token is invalid. So "401" gets returned under at least two conditions but there is a good human-readable error returned.
#
# Errors are also returned in JSON format. Nice!

# %% [markdown]
# ## /api/v1/search/ipv4/ test
# This endpoint allows us to search ipv4 address. But are these IPv4 addresses of sites hosting phishing sites? Or IPv4 addresses associated with phishing email senders?

# %%
# Search for an IP that will NOT be found (we tested in advance from known threat intel)
ip = '46.101.222.88'
url = f'{ep_ipv4}/{ip}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 200

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# []

# %% [markdown]
# ### Observations
# When the API call is successful, but nothing is found, the status code is "200", but the JSON is empty.

# %% [markdown]
# ### What about for a well-known IP?
# What happens when we put in a well-known IP that might be associated with a large number of legitimate and evil sites?

# %%
# Search for an IP that will NOT be found (we tested in advance from known threat intel)
ip = '1.1.1.1'
url = f'{ep_ipv4}/{ip}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 200

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 50

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# [
#   {
#     "siteurl": "http://facebook-com-pl.pl/",
#     "sitedomain": "facebook-com-pl.pl",
#     "pagetitle": "DNS resolution error | facebook-com-pl.pl | Cloudflare",
#     "firstseentime": "2022-02-28T15:12:30Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://facebook-pl-com.pl/",
#     "sitedomain": "facebook-pl-com.pl",
#     "pagetitle": "DNS resolution error | facebook-pl-com.pl | Cloudflare",
#     "firstseentime": "2022-02-28T15:10:19Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.moneystar123.xyz/",
#     "sitedomain": "www.moneystar123.xyz",
#     "pagetitle": "Edge IP Restricted | www.moneystar123.xyz | Cloudflare",
#     "firstseentime": "2022-02-04T12:42:52Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.153.contactmanagement.hu",
#     "sitedomain": "1.1.1.1",
#     "pagetitle": null,
#     "firstseentime": "2022-01-30T18:03:14Z",
#     "firstseencode": "200",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.microsoftonline.mcommon.authorize.homeauth.duckdns.org/",
#     "sitedomain": "www.microsoftonline.mcommon.authorize.homeauth.duckdns.org",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2022-01-20T07:33:07Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://au.kkdi.ceae.xyz/",
#     "sitedomain": "au.kkdi.ceae.xyz",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-12-30T04:13:14Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.euschool.wikaba.com/",
#     "sitedomain": "www.euschool.wikaba.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-12-10T02:42:58Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://zzyyzyzyyyzyzzzzyzyyyzzzyzyyzzyyyyyzzzzyzyzyyzzzyzitita4956.goserials.cc/%3Fzmhnuol55320%26amp%3Bfbclid%3D",
#     "sitedomain": "zzyyzyzyyyzyzzzzyzyyyzzzyzyyzzyyyyyzzzzyzyzyyzzzyzitita4956.goserials.cc",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-11-23T02:43:50Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://zzzyzzzzyyzyyzyyzyzzyzyzzzyyyzzyzyzzyzzyyzzzyzzzyyitita0898.goserials.cc/%3Fkihxlrb65326%26amp%3Bfbclid%3D",
#     "sitedomain": "zzzyzzzzyyzyyzyyzyzzyzyzzzyyyzzyzyzzyzzyyzzzyzzzyyitita0898.goserials.cc",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-11-17T16:43:09Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://oneconnect-guest.interpublic.com/",
#     "sitedomain": "oneconnect-guest.interpublic.com",
#     "pagetitle": "DNS resolution error | oneconnect-guest.interpublic.com | Cloudflare",
#     "firstseentime": "2021-11-17T11:51:08Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://nearform-covid-services.com/",
#     "sitedomain": "nearform-covid-services.com",
#     "pagetitle": "DNS resolution error | nearform-covid-services.com | Cloudflare",
#     "firstseentime": "2021-11-15T19:45:53Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://barclayswlc.barclaysguestwireless.net/",
#     "sitedomain": "barclayswlc.barclaysguestwireless.net",
#     "pagetitle": "DNS resolution error | barclayswlc.barclaysguestwireless.net | Cloudflare",
#     "firstseentime": "2021-11-10T13:14:58Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://wifilogin.hydro.mb.ca/",
#     "sitedomain": "wifilogin.hydro.mb.ca",
#     "pagetitle": "DNS resolution error | wifilogin.hydro.mb.ca | Cloudflare",
#     "firstseentime": "2021-10-27T08:42:00Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://start-z-e-r-o.com/",
#     "sitedomain": "start-z-e-r-o.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-10-13T09:57:57Z",
#     "firstseencode": "200",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://assistenza-titolare-poste-it-posteid-7372678.ddns.me/",
#     "sitedomain": "assistenza-titolare-poste-it-posteid-7372678.ddns.me",
#     "pagetitle": "L\u2019int\u00e9rim digital pour PME et grandes entreprises | Randstad Direct",
#     "firstseentime": "2021-10-12T19:01:48Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://toprewrds.com/visitor_fr_br/index_1_d.php%3Fdevice_name%3Ddesktop%26browser_name%3Dfirefox%26language%3Dfr-fr%26city%3Dparis%26clickid%3D1dc13usft52c8f28%26campaign%3D285%26user_id%3D1%26clickcost%3D0%26lander%3D897%26time%3D1630524245%26browser_version%3D78.0%26device_model%3Ddesktop%26device_brand%3Ddesktop%26resolution%3Ddesktop%26os_name%3Dwindows%26os_version%3D10.0%26country%3Dfrance%26country_code%3Dfr%26isp%3Dorange%26ip%3D80.12.67.62%26user_agent%3Dmozilla/5.0%2520",
#     "sitedomain": "toprewrds.com",
#     "pagetitle": "DNS resolution error | toprewrds.com | Cloudflare",
#     "firstseentime": "2021-10-11T11:11:56Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://rvvc.im/",
#     "sitedomain": "rvvc.im",
#     "pagetitle": null,
#     "firstseentime": "2021-10-03T18:48:59Z",
#     "firstseencode": "200",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://ffa-1-public.iogames.icu/",
#     "sitedomain": "ffa-1-public.iogames.icu",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-20T07:05:36Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://ssl.livezilla.net/",
#     "sitedomain": "ssl.livezilla.net",
#     "pagetitle": "DNS resolution error | ssl.livezilla.net | Cloudflare",
#     "firstseentime": "2021-09-15T09:22:32Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://axpo.group/",
#     "sitedomain": "axpo.group",
#     "pagetitle": "DNS resolution error | axpo.group | Cloudflare",
#     "firstseentime": "2021-09-13T23:52:04Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://funplus.aihelp.net/",
#     "sitedomain": "funplus.aihelp.net",
#     "pagetitle": "DNS resolution error | funplus.aihelp.net | Cloudflare",
#     "firstseentime": "2021-09-09T16:50:00Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://tth7.cn/",
#     "sitedomain": "tth7.cn",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-09T07:57:26Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://tth7.cn/",
#     "sitedomain": "tth7.cn",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-09T07:57:26Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://st1.bestibz.com/",
#     "sitedomain": "st1.bestibz.com",
#     "pagetitle": "DNS resolution error | st1.bestibz.com | Cloudflare",
#     "firstseentime": "2021-09-08T12:32:56Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://tujitest.taobao.com/%27",
#     "sitedomain": "tujitest.taobao.com",
#     "pagetitle": null,
#     "firstseentime": "2021-09-07T23:35:24Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://theoffertopo.com/visitor_fr_br/index_1_d.php%3Fdevice_name%3DDeskt...%2527",
#     "sitedomain": "theoffertopo.com",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-09-07T22:08:55Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://rodrigoferrari.org/%27",
#     "sitedomain": "rodrigoferrari.org",
#     "pagetitle": "Welcome",
#     "firstseentime": "2021-09-07T22:07:49Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://safe-installation.pt/%27",
#     "sitedomain": "safe-installation.pt",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-07T22:07:29Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cn.zjgslb.com/%27",
#     "sitedomain": "cn.zjgslb.com",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-09-07T21:53:59Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://hear-voice.jumpseller.com/%27",
#     "sitedomain": "hear-voice.jumpseller.com",
#     "pagetitle": "Google",
#     "firstseentime": "2021-09-07T21:50:12Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://hepcyburada.com/%27",
#     "sitedomain": "hepcyburada.com",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-09-07T21:49:14Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://t.trxsmartchain.com/%27",
#     "sitedomain": "t.trxsmartchain.com",
#     "pagetitle": "DNS resolution error | t.trxsmartchain.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:47:39Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://mail.migdigital.co.il/%27",
#     "sitedomain": "mail.migdigital.co.il",
#     "pagetitle": "DNS resolution error | mail.migdigital.co.il | Cloudflare",
#     "firstseentime": "2021-09-07T21:47:36Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://paolo-procedura-24-08-2021.jetos.com/%27",
#     "sitedomain": "paolo-procedura-24-08-2021.jetos.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-07T21:43:50Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://smilezam.ru/%27",
#     "sitedomain": "smilezam.ru",
#     "pagetitle": "Access denied | smilezam.ru used Cloudflare to restrict access",
#     "firstseentime": "2021-09-07T21:43:40Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://nowgames.net/%27",
#     "sitedomain": "nowgames.net",
#     "pagetitle": "Access denied | nowgames.net used Cloudflare to restrict access",
#     "firstseentime": "2021-09-07T21:42:59Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://metamask.extension.aursmon.com/images%27",
#     "sitedomain": "metamask.extension.aursmon.com",
#     "pagetitle": "DNS resolution error | metamask.extension.aursmon.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:41:10Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://getrewardsbest.com/visitor_fr/index_2_d.php%3Fdevice_name%3DDeskto...%2527",
#     "sitedomain": "getrewardsbest.com",
#     "pagetitle": "403 Forbidden",
#     "firstseentime": "2021-09-07T21:40:43Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://korberpie8p6f.servebeer.com/123/us18/28/%27",
#     "sitedomain": "korberpie8p6f.servebeer.com",
#     "pagetitle": "DNS resolution error | korberpie8p6f.servebeer.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:39:02Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://www.anst.it/%27",
#     "sitedomain": "www.anst.it",
#     "pagetitle": "DNS resolution error | www.anst.it | Cloudflare",
#     "firstseentime": "2021-09-07T21:35:52Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://shenzhenyuhuanshang.com/%27",
#     "sitedomain": "shenzhenyuhuanshang.com",
#     "pagetitle": "DNS resolution error | shenzhenyuhuanshang.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:29:35Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://prasetyaks.com/%27",
#     "sitedomain": "prasetyaks.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-07T21:28:52Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://yilifl.com/%27",
#     "sitedomain": "yilifl.com",
#     "pagetitle": "DNS resolution error | yilifl.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:25:50Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://accessonline.services/%27",
#     "sitedomain": "accessonline.services",
#     "pagetitle": "DNS resolution error | accessonline.services | Cloudflare",
#     "firstseentime": "2021-09-07T21:16:53Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://shafanikan.com/%27",
#     "sitedomain": "shafanikan.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-07T21:16:26Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://onlinebezt.com/visitor_fr/index_2_d.php%3Fdevice_name%3DDesktop%26br...%2527",
#     "sitedomain": "onlinebezt.com",
#     "pagetitle": null,
#     "firstseentime": "2021-09-07T21:14:02Z",
#     "firstseencode": "aborted",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://sciadv.top/archives/ed3f6904/%27",
#     "sitedomain": "sciadv.top",
#     "pagetitle": null,
#     "firstseentime": "2021-09-07T21:13:40Z",
#     "firstseencode": "403",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://web.iviso.xyz/%27",
#     "sitedomain": "web.iviso.xyz",
#     "pagetitle": "Not Found (#404) - \u5fc5\u5e94\u6bcf\u65e5\u58c1\u7eb8",
#     "firstseentime": "2021-09-07T21:11:15Z",
#     "firstseencode": "404",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://guest-ocsl.orange.com/%27",
#     "sitedomain": "guest-ocsl.orange.com",
#     "pagetitle": "DNS resolution error | guest-ocsl.orange.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:10:07Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://globaltoprewards.com/visitoronline_us_nonbr%27",
#     "sitedomain": "globaltoprewards.com",
#     "pagetitle": "DNS resolution error | globaltoprewards.com | Cloudflare",
#     "firstseentime": "2021-09-07T21:06:43Z",
#     "firstseencode": "409",
#     "ipaddress": "1.1.1.1",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations
# This shows a lot of sites protected by Cloudflare (1.1.1.1)
#
# It is interesting how many of these URLs end in "/%27". Which is a single-quote "'" in HTML encoding. I wonder if this is a parsing error or if it really was part of the phishing URL sent to a victim. Or perhaps it is some oddity related to Cloudflare.
#
# It is also interesting that most of the titles are "DNS Resolution Error". Is the title fetched by stalkphish? Does this occur because of a failure to fetch the actual webpage at the URL? Is it because Cloudflare blocked fetching the page? Or because the site was down by the time it was investigated?

# %%
# Search for IP that WILL be found
ip = '80.66.64.192'
url = f'{ep_ipv4}/{ip}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 6

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# [
#   {
#     "siteurl": "https://wallet-polygone.com/",
#     "sitedomain": "wallet-polygone.com",
#     "pagetitle": "Polygon Web Wallet v2",
#     "firstseentime": "2022-03-01T08:02:01Z",
#     "firstseencode": "200",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://mymoneria.com",
#     "sitedomain": "mymoneria.com",
#     "pagetitle": null,
#     "firstseentime": "2022-03-01T02:22:42Z",
#     "firstseencode": "200",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://openseca.com",
#     "sitedomain": "openseca.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:18Z",
#     "firstseencode": "timeout",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://roninwailet.com",
#     "sitedomain": "roninwailet.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:14:04Z",
#     "firstseencode": "aborted",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://roninwailet.com/",
#     "sitedomain": "roninwailet.com",
#     "pagetitle": "Welcome to Ronin \u2013 The Axie Infinity Wallet",
#     "firstseentime": "2022-02-28T23:13:41Z",
#     "firstseencode": "200",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://openseca.com/",
#     "sitedomain": "openseca.com",
#     "pagetitle": "OpenSea: Buy NFTs, Crypto Collectibles, CryptoKitties, Decentraland, and more on Ethereum",
#     "firstseentime": "2022-02-28T15:16:05Z",
#     "firstseencode": "200",
#     "ipaddress": "80.66.64.192",
#     "asn": "57416",
#     "asndesc": "INSTARS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations
# It is unclear if these are actually phishing sites. I got the IP address (80.66.64.192) from an existing entry in the StalkPhish API. I knew there would be at least one entry. Are all of these sites phishing sites? Or are they just hosted on the same IP? Was this discovered through Passive DNS?
#
# It would be helpful if the source of the database entry was known. For example, if the siteurl was added because it was suspected to be a phishing page, that is different than it being added via Passive DNS, revsere lookups, or via a redirection.
#
# If the URL was discovered because it was the target of a redirection it would be good know that association.

# %% [markdown]
# ## /api/v1/search/title test
# This searches for titles in web pages. Presumably in the pages for phishing sites. This would be great for cases where we have found a phishing site and want to see where else it has been used.
#
# For our test we will use several strings for titles we believe are unique: representing things we expect and DO NOT expect to find in phishing sites.

# %%
# Search for Page Titles
title = 'broker'
url = f'{ep_title}/{title}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of responses: {len(response.json())}')
# Out:
# Number of responses: 1

# %%
print(f'Respnse Status: {response.status_code}, {response.json()}')
# Out:
# Respnse Status: 401, {'error': "You don't have access to this search option with you profile"}

# %% [markdown]
# ### Observations for /title test
# response.status_code=401 occurs when you don't have access to this search option.
# The response will contain a JSON/dict item called "error" with value "You don't have access to this search option with you profile"
#
# If this did work, would the search be case-sensitive or case-insensitive?

# %% [markdown]
# ## /api/v1/search/url test
# This endpoint allows us to search URLs. It is not clear if we have supply a full URL or a string to search for in an URL. I think "string to search for".
#
# So for our first experiment we will search for a single string we expect to find results for.
#
# I am going to use "broker" related search terms. I work in the insurance industry and this term used in the URL of a phishing page would be of great interest to us.

# %%
# Search for emails containing "broker"
url_string = 'broker'

url = f'{ep_url}/{url_string}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 50

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 200

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# [
#   {
#     "siteurl": "https://broker.gov.teams.microsoft.us.office.m365.leidos.govshn.net",
#     "sitedomain": "broker.gov.teams.microsoft.us.office.m365.leidos.govshn.net",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T23:03:38Z",
#     "firstseencode": "aborted",
#     "ipaddress": "18.252.135.61",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cryptobank.broker",
#     "sitedomain": "cryptobank.broker",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T20:31:31Z",
#     "firstseencode": "200",
#     "ipaddress": "52.33.207.7",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguroportatil.sumbroker.es",
#     "sitedomain": "seguroportatil.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T17:36:47Z",
#     "firstseencode": "200",
#     "ipaddress": "20.86.168.124",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguropatinete.sumbroker.es",
#     "sitedomain": "seguropatinete.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T17:36:00Z",
#     "firstseencode": "200",
#     "ipaddress": "20.86.168.124",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguromultidispositivo.sumbroker.es",
#     "sitedomain": "seguromultidispositivo.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T17:35:39Z",
#     "firstseencode": "200",
#     "ipaddress": "20.86.168.124",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://broker.gov.teams.microsoft.us.office.gcch.leidos.govshn.net",
#     "sitedomain": "broker.gov.teams.microsoft.us.office.gcch.leidos.govshn.net",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T16:00:11Z",
#     "firstseencode": "502",
#     "ipaddress": "18.252.135.61",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://%2A.service-broker-cluster-",
#     "sitedomain": "*.service-broker-cluster-e40750a6150dc7e1cdb465eaf4188cdf-0000.us-south.containers.appdomain.cloud",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T07:23:36Z",
#     "firstseencode": "aborted",
#     "ipaddress": "52.117.197.3",
#     "asn": "36351",
#     "asndesc": "SOFTLAYER, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://rollcactus6.werite.net/post/2022/02/28/The-Single-Strategy-To-Use-For-What-is-IDX-IDX-Broker",
#     "sitedomain": "rollcactus6.werite.net",
#     "pagetitle": "The Single Strategy To Use For What is IDX? - IDX Broker - Busch Lauesen",
#     "firstseentime": "2022-02-28T06:47:15Z",
#     "firstseencode": "200",
#     "ipaddress": "157.245.145.14",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://status-credit-insurance-brokers-ltd.co.uk/",
#     "sitedomain": "status-credit-insurance-brokers-ltd.co.uk",
#     "pagetitle": "Hosted By One.com | Webhosting made simple",
#     "firstseentime": "2022-02-27T22:40:09Z",
#     "firstseencode": "200",
#     "ipaddress": "46.30.213.6",
#     "asn": "51468",
#     "asndesc": "ONECOM, DK",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://status-credit-insurance-brokers-ltd.co.uk",
#     "sitedomain": "status-credit-insurance-brokers-ltd.co.uk",
#     "pagetitle": null,
#     "firstseentime": "2022-02-27T22:30:03Z",
#     "firstseencode": "200",
#     "ipaddress": "46.30.213.6",
#     "asn": "51468",
#     "asndesc": "ONECOM, DK",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://release.workstationdcvbroker.us-east-1.prod.netflix.net",
#     "sitedomain": "release.workstationdcvbroker.us-east-1.prod.netflix.net",
#     "pagetitle": null,
#     "firstseentime": "2022-02-27T18:33:09Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://release.workstationdcvbroker.us-west-2.prod.netflix.net",
#     "sitedomain": "release.workstationdcvbroker.us-west-2.prod.netflix.net",
#     "pagetitle": null,
#     "firstseentime": "2022-02-27T18:30:13Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://broker.employeebenefitplatform.co/kk-solutions1",
#     "sitedomain": "broker.employeebenefitplatform.co",
#     "pagetitle": "Access denied | broker.employeebenefitplatform.co used Cloudflare to restrict access",
#     "firstseentime": "2022-02-27T03:18:08Z",
#     "firstseencode": "503",
#     "ipaddress": "104.16.16.194",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.g.demo.user.forex-brokers.pro",
#     "sitedomain": "forex-brokers.pro",
#     "pagetitle": null,
#     "firstseentime": "2022-02-27T02:29:53Z",
#     "firstseencode": "200",
#     "ipaddress": "190.115.18.222",
#     "asn": "262254",
#     "asndesc": "DDOS-GUARD CORP., BZ",
#     "asnreg": "lacnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://broker.employeebenefitplatform.co",
#     "sitedomain": "broker.employeebenefitplatform.co",
#     "pagetitle": null,
#     "firstseentime": "2022-02-27T02:17:58Z",
#     "firstseencode": "503",
#     "ipaddress": "104.16.14.194",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://service.graspinsurebroker.online",
#     "sitedomain": "service.graspinsurebroker.online",
#     "pagetitle": null,
#     "firstseentime": "2022-02-26T06:39:53Z",
#     "firstseencode": "200",
#     "ipaddress": "188.166.224.111",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://posta.generalriskbroker.it",
#     "sitedomain": "posta.generalriskbroker.it",
#     "pagetitle": null,
#     "firstseentime": "2022-02-26T03:13:06Z",
#     "firstseencode": "aborted",
#     "ipaddress": "37.159.177.94",
#     "asn": "30722",
#     "asndesc": "VODAFONE-IT-ASN, IT",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://moneypatternbroker.info",
#     "sitedomain": "moneypatternbroker.info",
#     "pagetitle": null,
#     "firstseentime": "2022-02-25T06:12:50Z",
#     "firstseencode": "200",
#     "ipaddress": "188.114.97.7",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://balmoralmortgagebrokers.com/sxde/Daum/Daum.html",
#     "sitedomain": "balmoralmortgagebrokers.com",
#     "pagetitle": "Daum \u00eb\u00a1\u009c\u00ea\u00b7\u00b8\u00ec\u009d\u00b8",
#     "firstseentime": "2022-02-24T13:03:46Z",
#     "firstseencode": "timeout",
#     "ipaddress": "192.254.232.227",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://balmoralmortgagebrokers.com/sxde/Daum/Daum1.html",
#     "sitedomain": "balmoralmortgagebrokers.com",
#     "pagetitle": "Daum \u00eb\u00a1\u009c\u00ea\u00b7\u00b8\u00ec\u009d\u00b8",
#     "firstseentime": "2022-02-24T13:03:26Z",
#     "firstseencode": "200",
#     "ipaddress": "192.254.232.227",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://broker.safetynetaccess.com",
#     "sitedomain": "broker.safetynetaccess.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-24T11:14:25Z",
#     "firstseencode": "200",
#     "ipaddress": "18.211.233.190",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cas-aws.vmwareidentity.com/cas/t/ADOBE/API/1.0/REST/landing%3FEAB_CALLBACK_URL%3D%252Fauth%252Flogin%252Fembeddedauthbroker%252Fcallback%252Fv2%253FhorizonRelayState%253Dctx_73d69bc4-77d9-40aa-b707-77e7403986b2_1860500815%26requestTimeout%3D15%26Idm-Trace-Id%3DRoot%253D1-62171a91-33b32a9d5eb789ca2ea9c272%253BParent%253D2afb09c91fcb311b%253BSampled%253D0",
#     "sitedomain": "cas-aws.vmwareidentity.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-24T07:17:25Z",
#     "firstseencode": "200",
#     "ipaddress": "34.210.255.147",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://broker.gov.teams.microsoft.us.office.rp1.abangaritest.govshn.net",
#     "sitedomain": "broker.gov.teams.microsoft.us.office.rp1.abangaritest.govshn.net",
#     "pagetitle": null,
#     "firstseentime": "2022-02-23T16:31:49Z",
#     "firstseencode": "502",
#     "ipaddress": "52.222.91.178",
#     "asn": "8987",
#     "asndesc": "AMAZON EXPANSION, IE",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://emerchantbrokeriso.com/pagepage.html",
#     "sitedomain": "emerchantbrokeriso.com",
#     "pagetitle": "Security Question",
#     "firstseentime": "2022-02-23T01:58:34Z",
#     "firstseencode": "200",
#     "ipaddress": "162.144.18.195",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://emerchantbrokeriso.com/index.html",
#     "sitedomain": "emerchantbrokeriso.com",
#     "pagetitle": "Security Question",
#     "firstseentime": "2022-02-23T01:57:44Z",
#     "firstseencode": "200",
#     "ipaddress": "162.144.18.195",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://credit-broker-rus.ru",
#     "sitedomain": "bankpro.su",
#     "pagetitle": null,
#     "firstseentime": "2022-02-22T12:39:03Z",
#     "firstseencode": "200",
#     "ipaddress": "159.69.232.149",
#     "asn": "24940",
#     "asndesc": "HETZNER-AS, DE",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://sjmauth.refahbroker.ir",
#     "sitedomain": "sjmauth.refahbroker.ir",
#     "pagetitle": null,
#     "firstseentime": "2022-02-22T08:36:22Z",
#     "firstseencode": "200",
#     "ipaddress": "185.147.161.201",
#     "asn": "43754",
#     "asndesc": "ASIATECH, IR",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.discovery.co.za/assets/template-resources/business-insurance/broker-quiz-questions.pdf%3Futm_source%3DDBI_newsletter%26utm_medium%3DEmail%26utm_campaign%3DDBI_newsletter_Feb2022",
#     "sitedomain": "www.discovery.co.za",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T12:43:06Z",
#     "firstseencode": "200",
#     "ipaddress": "107.154.80.49",
#     "asn": "19551",
#     "asndesc": "INCAPSULA, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.nogueirabrokers.controlrevenda.com.br",
#     "sitedomain": "nogueirabrokers.controlrevenda.com.br",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T12:35:57Z",
#     "firstseencode": "200",
#     "ipaddress": "177.53.143.221",
#     "asn": "53243",
#     "asndesc": "Brasil Site Informatica LTDA, BR",
#     "asnreg": "lacnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguromovil.sbx.sumbroker.es",
#     "sitedomain": "seguromovil.sbx.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T10:08:56Z",
#     "firstseencode": "200",
#     "ipaddress": "20.101.121.242",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguroportatil.sbx.sumbroker.es",
#     "sitedomain": "seguroportatil.sbx.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T10:08:43Z",
#     "firstseencode": "200",
#     "ipaddress": "20.101.121.242",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cliente.sbx.sumbroker.es",
#     "sitedomain": "cliente.sbx.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T10:08:15Z",
#     "firstseencode": "200",
#     "ipaddress": "20.101.121.242",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguromultidispositivo.sbx.sumbroker.es",
#     "sitedomain": "seguromultidispositivo.sbx.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T10:08:07Z",
#     "firstseencode": "200",
#     "ipaddress": "20.101.121.242",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://seguropatinete.sbx.sumbroker.es",
#     "sitedomain": "seguropatinete.sbx.sumbroker.es",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T10:07:19Z",
#     "firstseencode": "200",
#     "ipaddress": "20.101.121.242",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://QueryBrokerService.FXP.manage.microsoft.us",
#     "sitedomain": "QueryBrokerService.FXP.manage.microsoft.us",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T02:07:07Z",
#     "firstseencode": "400",
#     "ipaddress": "52.247.174.16",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://auth.uabroker-db.com",
#     "sitedomain": "auth.uabroker-db.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-21T00:13:30Z",
#     "firstseencode": "200",
#     "ipaddress": "143.204.98.81",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://support.landbrokermls.com",
#     "sitedomain": "support.landbrokermls.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T23:08:24Z",
#     "firstseencode": "200",
#     "ipaddress": "35.168.141.105",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.broker-service.org",
#     "sitedomain": "www.broker-service.org",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T22:06:46Z",
#     "firstseencode": "200",
#     "ipaddress": "91.195.240.87",
#     "asn": "47846",
#     "asndesc": "SEDO-AS, DE",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://broker-service.org",
#     "sitedomain": "broker-service.org",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T22:03:38Z",
#     "firstseencode": "200",
#     "ipaddress": "91.195.240.87",
#     "asn": "47846",
#     "asndesc": "SEDO-AS, DE",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.billyhickey.propertybrokers.co.nz",
#     "sitedomain": "www.billyhickey.co.nz",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T20:10:15Z",
#     "firstseencode": "200",
#     "ipaddress": "13.211.100.145",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://friendsandfamily.brokeradminsupport.medicaresuggest.com",
#     "sitedomain": "friendsandfamily.brokeradminsupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:11:58Z",
#     "firstseencode": "403",
#     "ipaddress": "52.54.154.119",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://friendsandfamily.brokersupport.medicaresuggest.com",
#     "sitedomain": "friendsandfamily.brokersupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:11:43Z",
#     "firstseencode": "403",
#     "ipaddress": "34.192.143.148",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://gordonmarketing.brokeradminsupport.medicaresuggest.com",
#     "sitedomain": "gordonmarketing.brokeradminsupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:11:03Z",
#     "firstseencode": "403",
#     "ipaddress": "34.192.143.148",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://gordonmarketing.brokersupport.medicaresuggest.com",
#     "sitedomain": "gordonmarketing.brokersupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:10:46Z",
#     "firstseencode": "403",
#     "ipaddress": "52.54.154.119",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://inspireht.brokersupport.medicaresuggest.com",
#     "sitedomain": "inspireht.brokersupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:10:20Z",
#     "firstseencode": "403",
#     "ipaddress": "34.192.143.148",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://prodash.brokeradminsupport.medicaresuggest.com",
#     "sitedomain": "prodash.brokeradminsupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:10:06Z",
#     "firstseencode": "403",
#     "ipaddress": "54.164.79.255",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://prodash.brokersupport.medicaresuggest.com",
#     "sitedomain": "prodash.brokersupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:10:00Z",
#     "firstseencode": "403",
#     "ipaddress": "54.159.76.221",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://ritterim.brokeradminsupport.medicaresuggest.com",
#     "sitedomain": "ritterim.brokeradminsupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:09:34Z",
#     "firstseencode": "403",
#     "ipaddress": "34.192.143.148",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://securityhealthplan.brokeradminsupport.medicaresuggest.com",
#     "sitedomain": "securityhealthplan.brokeradminsupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:09:15Z",
#     "firstseencode": "403",
#     "ipaddress": "52.44.157.236",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://ritterim.brokersupport.medicaresuggest.com",
#     "sitedomain": "ritterim.brokersupport.medicaresuggest.com",
#     "pagetitle": null,
#     "firstseentime": "2022-02-20T09:09:12Z",
#     "firstseencode": "403",
#     "ipaddress": "54.159.76.221",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations
# These do look like evil sites for the most part.
#
# This one appears to be a parsing error of some kind. Maybe it was autodiscovered when stalkphish followed a link on another site being investigated? The "siteurl" might be missing part of the string.
#
# `
# {
#     "siteurl": "https://%2A.service-broker-cluster-",
#     "sitedomain": "*.service-broker-cluster-e40750a6150dc7e1cdb465eaf4188cdf-0000.us-south.containers.appdomain.cloud",
#     "pagetitle": null,
#     "firstseentime": "2022-02-28T07:23:36Z",
#     "firstseencode": "aborted",
#     "ipaddress": "52.117.197.3",
#     "asn": "36351",
#     "asndesc": "SOFTLAYER, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
# `

# %% [markdown]
# ### Search for "claimant"
# Another command string in URLs for legitimate insurance sites is "claimant". This is also used in legal sites.

# %%
# Search for URls containing "claimant"
url_string = 'claimant'

url = f'{ep_url}/{url_string}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 34

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 200

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# [
#   {
#     "siteurl": "https://www.lorman.com/training/workers-comp/employment-law-compliance-disciplining-or-terminating-a-workers-compensation-claimant%3Fp%3D19644%26utm_medium%3Demail%26utm_source%3Ddigest%26utm_campaign%3Dhrtest2022%26mkt_tok%3DODQwLVVaUS0wNDQAAAGCmCvmrFBWnf50JxaXVx25gb-Nbbe7Jzk8Msi1_-0hBAQJvZN0TEne4-_RgAlGUU8tgpyOY0lITZnsyyLAhVVcWocW--U5eyoU4isbh365uzSc",
#     "sitedomain": "www.lorman.com",
#     "pagetitle": "Attention Required! | Cloudflare",
#     "firstseentime": "2022-02-14T17:38:30Z",
#     "firstseencode": "200",
#     "ipaddress": "104.26.3.49",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://indianaunemploymentclaimantlogin.com",
#     "sitedomain": "indianaunemploymentclaimantlogin.com",
#     "pagetitle": null,
#     "firstseentime": "2022-01-29T08:05:15Z",
#     "firstseencode": "aborted",
#     "ipaddress": "81.17.18.197",
#     "asn": "51852",
#     "asndesc": "PLI-AS, PA",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://australiaclaimantagentsupport.zendesk.com",
#     "sitedomain": "australiaclaimantagentsupport.zendesk.com",
#     "pagetitle": null,
#     "firstseentime": "2022-01-25T01:28:18Z",
#     "firstseencode": "200",
#     "ipaddress": "162.159.128.7",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://australiaclaimantagentsupport.zendesk.com",
#     "sitedomain": "australiaclaimantagentsupport.zendesk.com",
#     "pagetitle": null,
#     "firstseentime": "2022-01-25T01:28:18Z",
#     "firstseencode": "200",
#     "ipaddress": "162.159.128.7",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://australiaclaimantagentsupport.zendesk.com",
#     "sitedomain": "australiaclaimantagentsupport.zendesk.com",
#     "pagetitle": null,
#     "firstseentime": "2022-01-25T01:28:18Z",
#     "firstseencode": "200",
#     "ipaddress": "162.159.138.6",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://claimantbeaconmd.cloudns.nz",
#     "sitedomain": "claimantbeaconmd.cloudns.nz",
#     "pagetitle": null,
#     "firstseentime": "2022-01-24T17:24:50Z",
#     "firstseencode": "200",
#     "ipaddress": "161.35.238.202",
#     "asn": "14061",
#     "asndesc": "DIGITALOCEAN-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://wawanesa-dev.stg.zmbl.io/sign_in/claimant",
#     "sitedomain": "wawanesa-dev.stg.zmbl.io",
#     "pagetitle": "Claims Portal",
#     "firstseentime": "2022-01-24T16:07:37Z",
#     "firstseencode": "200",
#     "ipaddress": "99.86.3.12",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://beacon.labour-maryland.online/ReBEACONClaimants/Account/",
#     "sitedomain": "beacon.labour-maryland.online",
#     "pagetitle": "One moment, please...",
#     "firstseentime": "2021-12-13T07:15:43Z",
#     "firstseencode": "200",
#     "ipaddress": "64.20.38.211",
#     "asn": "19318",
#     "asndesc": "IS-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://support.aclaimant.com/hc/en-us",
#     "sitedomain": "support.aclaimant.com",
#     "pagetitle": null,
#     "firstseentime": "2021-10-01T22:26:27Z",
#     "firstseencode": "200",
#     "ipaddress": "104.16.53.111",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://idaho-development-claimantportal-authentication-web.id.development.ius.gov/",
#     "sitedomain": "idaho-development-claimantportal-authentication-web.id.development.ius.gov",
#     "pagetitle": null,
#     "firstseentime": "2021-08-17T17:45:41Z",
#     "firstseencode": "200",
#     "ipaddress": "40.125.97.21",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://uiclaimantportal.labor.alabama.gov/Home/Contact",
#     "sitedomain": "uiclaimantportal.labor.alabama.gov",
#     "pagetitle": "Contact Us: Alabama Claimant Portal",
#     "firstseentime": "2021-08-13T23:48:05Z",
#     "firstseencode": "200",
#     "ipaddress": "52.153.229.76",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.claimantselfservice.com/",
#     "sitedomain": "www.claimantselfservice.com",
#     "pagetitle": null,
#     "firstseentime": "2021-08-09T02:56:08Z",
#     "firstseencode": "200",
#     "ipaddress": "160.153.136.3",
#     "asn": "21501",
#     "asndesc": "GODADDY-AMS, DE",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www2.labor.idaho.gov/ClaimantPortal/review/document",
#     "sitedomain": "www2.labor.idaho.gov",
#     "pagetitle": null,
#     "firstseentime": "2021-08-02T13:55:26Z",
#     "firstseencode": "aborted",
#     "ipaddress": "204.144.104.66",
#     "asn": "54885",
#     "asndesc": "STATE-OF-IDAHO-SECONDARY-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://riotdivorce.com/idaho/Login-IDOL%2520Claimant%2520Portal.htm",
#     "sitedomain": "riotdivorce.com",
#     "pagetitle": null,
#     "firstseentime": "2021-08-02T13:51:37Z",
#     "firstseencode": "404",
#     "ipaddress": "92.223.93.168",
#     "asn": "199524",
#     "asndesc": "GCORE, LU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://boomstixaudio.com/claimantides/IDES.html",
#     "sitedomain": "boomstixaudio.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-26T22:23:09Z",
#     "firstseencode": "200",
#     "ipaddress": "92.223.105.18",
#     "asn": "199524",
#     "asndesc": "GCORE, LU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://uid.dli.mt.gov/claimants/report-hours-and-earnings.html",
#     "sitedomain": "uid.dli.mt.gov",
#     "pagetitle": null,
#     "firstseentime": "2021-07-21T02:17:22Z",
#     "firstseencode": "200",
#     "ipaddress": "161.7.31.28",
#     "asn": "3482",
#     "asndesc": "MTSTGOV, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://auth-pua-delawareworks02.herokuapp.com/NeosurancePUAClaimant/LoginReturnUrl/Account/",
#     "sitedomain": "auth-pua-delawareworks02.herokuapp.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-21T01:12:51Z",
#     "firstseencode": "404",
#     "ipaddress": "3.221.43.225",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://myunemployment-wisconsin-gov-claimant-logonssd.s3.us-east-2.amazonaws.com/Logon.htm",
#     "sitedomain": "myunemployment-wisconsin-gov-claimant-logonssd.s3.us-east-2.amazonaws.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-14T13:02:34Z",
#     "firstseencode": "200",
#     "ipaddress": "52.219.101.210",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.claimant.linkstarinfosys.com/",
#     "sitedomain": "www.claimant.linkstarinfosys.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-08T10:57:45Z",
#     "firstseencode": "200",
#     "ipaddress": "43.225.55.254",
#     "asn": "394695",
#     "asndesc": "PUBLIC-DOMAIN-REGISTRY, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://report.claims.statefarm.com/claimant/%3FlossType%3Dauto%26reporterType%3DotherInsuranceCompany",
#     "sitedomain": "report.claims.statefarm.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-06T22:33:44Z",
#     "firstseencode": "200",
#     "ipaddress": "13.225.87.99",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://myunemploymentswisc88.wixsite.com/benefit-claimant",
#     "sitedomain": "myunemploymentswisc88.wixsite.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-01T17:02:13Z",
#     "firstseencode": "404",
#     "ipaddress": "35.242.251.130",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.smithfreed.com/legal-updates/is-uim-coverage-for-claimants-in-insured-vehicles-on-the-horizon-in-oregon/%3Futm_campaign%3DWeekly%2520Email%26utm_medium%3Demail%26_hsmi%3D136049367%26_hsenc%3Dp2ANqtz--bBDUmw127sObN7F_eqGFxzbyKfU549V9P2lLPM0R01HruXLYGtuSiYqz5QaLFqhwzI-NrKfxAWDSkIqlRLx9AY6Xr9A%26utm_content%3D136049367%26utm_source%3Dhs_email",
#     "sitedomain": "www.smithfreed.com",
#     "pagetitle": null,
#     "firstseentime": "2021-06-24T19:34:50Z",
#     "firstseencode": "403",
#     "ipaddress": "104.21.41.183",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://workforcewv.site/Claimant/Account/Logon/Index",
#     "sitedomain": "workforcewv.site",
#     "pagetitle": null,
#     "firstseentime": "2021-06-23T17:27:20Z",
#     "firstseencode": "404",
#     "ipaddress": "102.130.117.212",
#     "asn": "328364",
#     "asndesc": "Host-Africa-AS, ZA",
#     "asnreg": "afrinic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://uinm.site/Claimant/Account/Logon/Index",
#     "sitedomain": "uinm.site",
#     "pagetitle": null,
#     "firstseentime": "2021-06-23T17:24:17Z",
#     "firstseencode": "aborted",
#     "ipaddress": "",
#     "asn": "",
#     "asndesc": "",
#     "asnreg": "",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://delawarework.site/Claimant/Account/Logon/Index",
#     "sitedomain": "delawarework.site",
#     "pagetitle": null,
#     "firstseentime": "2021-06-23T17:20:17Z",
#     "firstseencode": "404",
#     "ipaddress": "102.130.117.212",
#     "asn": "328364",
#     "asndesc": "Host-Africa-AS, ZA",
#     "asnreg": "afrinic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://connect.myflorida.com/Claimant/Core/Navigate.ASPX",
#     "sitedomain": "connect.myflorida.com",
#     "pagetitle": null,
#     "firstseentime": "2021-06-14T20:40:55Z",
#     "firstseencode": "aborted",
#     "ipaddress": "52.224.76.214",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://floridaunmploymentclaimantlogin.weebly.com/",
#     "sitedomain": "floridaunmploymentclaimantlogin.weebly.com",
#     "pagetitle": null,
#     "firstseentime": "2021-05-11T18:00:47Z",
#     "firstseencode": "timeout",
#     "ipaddress": "199.34.228.53",
#     "asn": "27647",
#     "asndesc": "WEEBLY, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www2-ill.inois-gov.live/Claimant/Core/Login/",
#     "sitedomain": "www2-ill.inois-gov.live",
#     "pagetitle": null,
#     "firstseentime": "2021-05-06T18:02:15Z",
#     "firstseencode": "404",
#     "ipaddress": "23.254.228.234",
#     "asn": "54290",
#     "asndesc": "HOSTWINDS, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://portal.edd.ca.gov/WebApp/Login%3Fresource_url%3Dhttps%253A%252F%252Fuio.edd.ca.gov%25252FUIO%25252FPages%25252FExternalUser%25252FClaimantAccountManagement%25252FDisplay1099GForms.aspx",
#     "sitedomain": "portal.edd.ca.gov",
#     "pagetitle": null,
#     "firstseentime": "2021-04-12T22:33:47Z",
#     "firstseencode": "aborted",
#     "ipaddress": "67.157.248.24",
#     "asn": "1226",
#     "asndesc": "CTA-42-AS1226, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://kccsecure.com/autopartsettlement/en-us/Claimant/Login",
#     "sitedomain": "kccsecure.com",
#     "pagetitle": null,
#     "firstseentime": "2021-04-11T06:07:41Z",
#     "firstseencode": "404",
#     "ipaddress": "12.183.16.70",
#     "asn": "2386",
#     "asndesc": "INS-AS, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www2.labor.idaho.gov/ClaimantPortal/Login/EmailVerification/egxkzgr7MtTNt08PBInM4vScDlr7BHhFgLWpD0SQYMwnEXDx52ZJ6G5Vbwb8rCXI",
#     "sitedomain": "www2.labor.idaho.gov",
#     "pagetitle": null,
#     "firstseentime": "2021-04-11T06:04:04Z",
#     "firstseencode": "aborted",
#     "ipaddress": "204.144.104.66",
#     "asn": "54885",
#     "asndesc": "STATE-OF-IDAHO-SECONDARY-ASN, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://corona-19claimants.com/",
#     "sitedomain": "corona-19claimants.com",
#     "pagetitle": null,
#     "firstseentime": "2020-05-24T08:05:24Z",
#     "firstseencode": "200",
#     "ipaddress": "184.168.221.44",
#     "asn": "26496",
#     "asndesc": null,
#     "asnreg": null,
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://live-fauna-flora-international.pantheonsite.io/grossisse.enchainement.contrre/claimant/TttTttTtt/Irlando",
#     "sitedomain": "live-fauna-flora-international.pantheonsite.io",
#     "pagetitle": null,
#     "firstseentime": "2020-01-07T16:11:55Z",
#     "firstseencode": "404",
#     "ipaddress": "23.185.0.2",
#     "asn": "54113",
#     "asndesc": null,
#     "asnreg": null,
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://kccsecure.com/sleepdevicesettlement/Claimant",
#     "sitedomain": "kccsecure.com",
#     "pagetitle": null,
#     "firstseentime": "2019-11-18T20:31:35Z",
#     "firstseencode": "200",
#     "ipaddress": "12.183.16.70",
#     "asn": "2386",
#     "asndesc": null,
#     "asnreg": null,
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observations
# Many of these appear to be legitimate insurance sites and are veribably not phishing sites.
#
# For example, this appears to be a legit StateFarm claims form:
#
# `
# {
#     "siteurl": "https://report.claims.statefarm.com/claimant/%3FlossType%3Dauto%26reporterType%3DotherInsuranceCompany",
#     "sitedomain": "report.claims.statefarm.com",
#     "pagetitle": null,
#     "firstseentime": "2021-07-06T22:33:44Z",
#     "firstseencode": "200",
#     "ipaddress": "13.225.87.99",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
# `
#
# Another example, this site is from a company called "Claims Space" that recently rebranded to "Zemble" (zmbl.io). This isn't a phishing site. But 99.86.3.12 is probably hosting many different sites. It is unclear what the relationship of this record is to phishing sites.
#
# `
# {
#     "siteurl": "https://wawanesa-dev.stg.zmbl.io/sign_in/claimant",
#     "sitedomain": "wawanesa-dev.stg.zmbl.io",
#     "pagetitle": "Claims Portal",
#     "firstseentime": "2022-01-24T16:07:37Z",
#     "firstseencode": "200",
#     "ipaddress": "99.86.3.12",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
# `

# %% [markdown]
# ### What about URLs with paths in them?
# Can we search for a full URL? Let's continue our last experiment but with a known full URL and see what happens. We will use a URL with a lot of URL encoded characters.

# %%
# Search for a specific URL
url_string = 'https://id.moneyforward.com/sign_in/email%3Fclient_id%3DOdII7gHa4v8Oouz6IbXSdRrVkTdbdzyISbOdEpEv070%26nonce%3D'

url = f'{ep_url}/{url_string}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 0

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 200

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# []

# %% [markdown]
# ### Observations
# That did not work. That URL is known to be in the database. Perhaps it is encoded characters? Let's try with a simpler URL

# %%
# Search for a specific URL (simpler this time)
url_string = 'http://corona-19claimants.com/'

url = f'{ep_url}/{url_string}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 1

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 429

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "detail": "Request was throttled. Expected available in 82410 seconds."
# }

# %% [markdown]
# ### Observations
# Doh! Throttled again.

# %% [markdown]
# ### What about a "/" in the URL? Can we search for a more than a simple string?
# The string "sign_in" appears in many phishing URLs. It should have many matches. So, we would need to narrow our search. Let's see if we can include path elements in the string. Some REST APIs cannot handle that OR require special encoding to handle it.

# %%
# Search for URLs containing "sign_in" with a slash
url_string = 'sign_in/'

url = f'{ep_url}/{url_string}'
try:
    response = requests.request("GET", url, headers=headers)
except Exception as e:
    print(f'Err: {e}')

# %%
print(f'Number of results: {len(response.json())}')
# Out:
# Number of results: 50

# %%
print(f'Response Status: {response.status_code}')
# Out:
# Response Status: 200

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# [
#   {
#     "siteurl": "https://etadka.com/wp-admin/user/webmail.cpanel.net/cpanel_mailbox/cp.user.sign_in/auth/index.htm",
#     "sitedomain": "etadka.com",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2022-02-21T11:21:43Z",
#     "firstseencode": "525",
#     "ipaddress": "188.114.97.0",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cl4uat.b2clogin.com/cl4uat.onmicrosoft.com/b2c_1_sign_up-sign_in/oauth2/v2.0/authorize%3Fclient_id%3D7723836e-7255-4999-a2fe-2324b23fed3c%26redirect_uri%3Dhttps%253A%252F%252Fqa13509-claims.aqvision.dev%252Fsignin-oidc%26response_type%3Did_token%26scope%3Dopenid%2520profile%26response_mode%3Dform_post%26nonce%3D637805053243726215.MGEyMzk0OGMtMTU5Zi00ZmQ5LTgzN2MtZDIyMTAxMWNhYTEwNjkwNjBlMzItY2U5YS00Y2QxLWE4YjUtMDVlMjY0Yzk3ZjMw%26state%3DCfDJ8Dhbj1ZSx4hFtZz9J_0JzjIkEQhzXp_f4m2Txjb5hoJCdXM_Opwmyx3heOsbkJp-MNvOGt88VUqi4yKf1MBF9FJdI8bKm7cgcO42OiqQA9Th5AGJUVy9j3gdoe5xUip6vhqyIaE2SdPYq9FPQn-CB1dAtk3vG6DJK6MELTWPqPBKxUnWSfZfhznUdc-FdECBVj_9DfpBsDUyft4Z-ETkC7BMh1WayXuk6sF1QQA93jZbuQODUKdhTmxM6nHuhpe0fVGQASYOtavVlSUIxOWeWG2qTXYuV1WhO6xX5bdOymAuUsshNx17Nl6iKf2M_qv_R2CY4wez-29Ns7r004Fpd0GjRCUv9hYTAF4Cc2ZlRXQUfMbfoQhrR0VaVuqV4-Alsrv1dY0SAv7_opJAFHJDq0TUQ2MVZwqKGeTAuqHDfwbHh05Bdqatu_K1mF2rgJQUysl-PCSe4OO4quBD6J_FEOqVZtEl-czL6spxgddDGkHXEitsV14c5klUlJh4Hjz3hC5s2sfcXWYGFYs3xfxowfY%26x-client-SKU%3DID_NETSTANDARD2_0%26x-client-ver%3D5.6.0.0",
#     "sitedomain": "cl4uat.b2clogin.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-15T07:07:21Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.4",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cl4uat.b2clogin.com/cl4uat.onmicrosoft.com/b2c_1_sign_up-sign_in/oauth2/v2.0/authorize%3Fclient_id%3D7723836e-7255-4999-a2fe-2324b23fed3c%26redirect_uri%3Dhttps%253A%252F%252Fqa13523-claims.aqvision.dev%252Fsignin-oidc%26response_type%3Did_token%26scope%3Dopenid%2520profile%26response_mode%3Dform_post%26nonce%3D637805053425449544.NGQ0OWUyOGUtZjg1Mi00NWVlLWFlMDItNWZmM2VmODUxZDZhNmUwZDViZmYtYjM3My00MmFkLWEzYzMtMjZjNjlmMjViNzI0%26state%3DCfDJ8AjINMgAT01HoE7YOIWbjzjmM0aK0tHO_T10t1ri-F02RPpJXheAysWNeUxqC8u04CLe6EGp2knPB5ipHAarZ5uYlKEOZ9Tcd_99x-TcV0om_fdqL3NM84bwAwKys1Tf_kfH7jjnfvlZHI4Ma_ldhLgtsq-VJrQ7M0EA_0IKqRsSPmGVvtGcBboyhQMi-fyFMmPoQAjtPhmIATvBE5JBGnR1K0sEO74hXcouZnCEHPFiwnqbg5L9WCmV2oOHwh8Qk9bdMCSDtl0N6UNWGSjDNGSxMChsncFCD2Qawy1kotHB2Q7AQ9Pb5NHV4evhxAMm9Hvy32F0ed53alyE7Mt-iBgIOtqziuziMnBl0TxLAFLkwfMgXz0fgYTZNNLZ2kKOjfIFTquuFziayZdoiWv2iDg3zP0vS4WeCyUKmpTAdijFCpNKN7AxTIgDSaFFpW_S7ujjCHYHYaQGEMSOvQw5cJLK-OuKACtzV0ewjJDGGlbkKzP6xzyXm0fE0fBc0y2vtsY-nPuJFpiweqSMcCfruSs%26x-client-SKU%3DID_NETSTANDARD2_0%26x-client-ver%3D5.6.0.0",
#     "sitedomain": "cl4uat.b2clogin.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-15T07:02:48Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.139",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://mazahub.com/wordpress/webmail.cpanel.net/cp.user.sign_in/webmail.cpanel.net_auth.mail~login_cPanel.mailbox.user.htm",
#     "sitedomain": "mazahub.com",
#     "pagetitle": "Webmail Login",
#     "firstseentime": "2022-02-09T15:13:09Z",
#     "firstseencode": "aborted",
#     "ipaddress": "207.244.245.116",
#     "asn": "40021",
#     "asndesc": "CONTABO, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cl4uat.b2clogin.com/cl4uat.onmicrosoft.com/b2c_1_sign_up-sign_in/oauth2/v2.0/authorize%3Fclient_id%3D7723836e-7255-4999-a2fe-2324b23fed3c%26redirect_uri%3Dhttps%253A%252F%252Fqa12664-claims.aqvision.dev%252Fsignin-oidc%26response_type%3Did_token%26scope%3Dopenid%2520profile%26response_mode%3Dform_post%26nonce%3D637787638819178923.ZDY0YmVhYjgtODNhOC00NTIxLTllODQtMzNlZTM4ZjhkMWVjZTQxOTQ0MjUtOWY4MS00OWFkLWI4MzEtNDhlMzVhMTljODg0%26state%3DCfDJ8H7MG5jzW7NGptXJfBjS0NBsq9JutlESJHkJzF1_21wYluXyslmB_UgKnmbrgD_yv3siNmpOUZJHwzoqFXpAdWf238BXKufLholOXubFlojsO-6qMzbkTBEdK4_UIk7YeAN0lP3z5upMii1_kYc0UugROPmLjUPsfYNk3XAGFHO1lLb73dkZSlgCALGLC_Svll72qIWe-EResMINAjo8tspXFSmGqkU-b0aYfw5YOTnMzpMCtv7fMhDKH7Ukd_hhzMG0hugrnhPpzUPsLMTIZ1e0e3xjq73KXysUJUuRbfZfyZbPJEmgpDxAEC17dqABZ8QKO-tvv5YJwN7LzIQiMN-Fwgvwz9DT5AG5EQYfdB_yUH3aAe21JfSvwDGuuyeGk_dYWLfGEz4nFFmx0hffphjaZjAeya1KgXGDHzwEvcb_O8S5d9HGzcc_4jd2nKh-IfSAzpqklWDET5l91cwYin9vu-Nn_RV8OnqHb1PySiPoAWa5LuxnSqtsX0aa3DSmijzHRIyqjcvDCi5ymLa3l1c%26x-client-SKU%3DID_NETSTANDARD2_0%26x-client-ver%3D5.6.0.0",
#     "sitedomain": "cl4uat.b2clogin.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-01-26T03:40:29Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.141",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cl4uat.b2clogin.com/cl4uat.onmicrosoft.com/b2c_1_sign_up-sign_in/oauth2/v2.0/authorize%3Fclient_id%3D7723836e-7255-4999-a2fe-2324b23fed3c%26redirect_uri%3Dhttps%253A%252F%252Fqa12648-claims.aqvision.dev%252Fsignin-oidc%26response_type%3Did_token%26scope%3Dopenid%2520profile%26response_mode%3Dform_post%26nonce%3D637787639225369228.MTMwZmRkZWMtOTg3My00NWE3LTkyNGItMDAxNzU3NTM5NGFjZjQ3ZTdmNDUtYzQ1NS00OTNiLWI3ODktYjFiMjJkOTQ3YmQ2%26state%3DCfDJ8G-_BzURLfhAo6EwJNjVSJx4JfRaO-4q3I1e8bxN-wM_uK3ZINIoWd0sJjBtCSbz2Vxo5-9DmI9hEL7lMywToaQvF37IcXngDTACImlY_fKOlYNDKSgnLHBHHoK3rOw72X1Hr_vcgfWOFHTfL3NWdZZkZqpWa9vlkSVvusIwcsZmKxC9PfDIPSj7E7k7NLJomRJbM6r_TCJoAXx3TAxOKEflQaYmWRmvkE5ew0IteCGNWfjr_4IOY8OBbf3POjmGIvX6tm6KFoGeEJRzcpz420lOBkDCjjxgiA2hOqMxhC0JeqRjqzLLVG9BbrIPMS6v3iMEzCjSy5Q3IUd092hfQVCG9KXcc7sX66BDqn8qVhvda9BLFDiTfUJhO2E6e-PGy3g7xOlzBFvxjjTBe6YR9RZiNj4TmwkFEQbitbHc-WJWA4Q1aF5LiJc6QHGJNXqG6tITlylim-0Y-wnj6vL3BqFn9OFGIKuhIz3QDonLMaEFPzfUPcN68e0rLAAhlT4baab36u6dtqlq0ry73Nn1YjY%26x-client-SKU%3DID_NETSTANDARD2_0%26x-client-ver%3D5.6.0.0",
#     "sitedomain": "cl4uat.b2clogin.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-01-26T03:34:31Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.135",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://wawanesa-dev.stg.zmbl.io/sign_in/claimant",
#     "sitedomain": "wawanesa-dev.stg.zmbl.io",
#     "pagetitle": "Claims Portal",
#     "firstseentime": "2022-01-24T16:07:37Z",
#     "firstseencode": "200",
#     "ipaddress": "99.86.3.12",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://cl4uat.b2clogin.com/cl4uat.onmicrosoft.com/b2c_1_sign_up-sign_in/oauth2/v2.0/authorize%3Fclient_id%3D7723836e-7255-4999-a2fe-2324b23fed3c%26redirect_uri%3Dhttps%253A%252F%252Faqa12738-claims.aqvision.dev%252Fsignin-oidc%26response_type%3Did_token%26scope%3Dopenid%2520profile%26response_mode%3Dform_post%26nonce%3D637784075252722975.ZGM3NmNmY2QtMjYzOS00ZWM3LWFlN2EtZDMzZTBjOGNjYjBmY2FmMTYwNjYtMDMzMS00OWQ1LWE0MjUtZDBlN2RlYTE1OGY2%26state%3DCfDJ8MIYwMBojvtMnIOMpAvIaa1S9WCVruu5Z-qm36Ti90uATj7yhRhtyZ9eEiFmD6TgNc-XAO3O2KET2HxTvchv61HuNh0sHQ1lxbKnW0gyboT7XaJzvQxZbi3u-pITYw3yX19y28PZfudJ0wp8sDVHLuDRrF9QT2Nni6GTmJ32JDAo96UmwWehkYeJzLbyS8t7Ca4TRFQezOH96lusPVywNewc7-FA-dmN1qoWdhlUonvqYNMJpkygYmUO3qKhyxFslbBdyoLLVQG9lYLfrEZh_rGNN1B9iqrDCublDSrNBPlx2dWLsMrrfMCBF5MvyrZFdw0B9OanRSwWhzSaqIF19P0043FIFNnY_PxNJdl_qdXsVGnx2NTgfYXjrKHhXe5kcGxjPp05NbuR82OH1alGShgQPzqLH4dlVPF9pLtKB6LoBdC_eCevTah-vcW8C4FCtDBCBO4l8BF8GWYj4LK2nTX3kbSSNOClqsMVd964eY5nis9OQ6qVS22YguIiafUe-ZpgDbuROvezbwagnLdjngg%26x-client-SKU%3DID_NETSTANDARD2_0%26x-client-ver%3D5.6.0.0",
#     "sitedomain": "cl4uat.b2clogin.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-01-22T01:58:30Z",
#     "firstseencode": "400",
#     "ipaddress": "40.126.31.1",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://srv-caixabanknow-sign-es.com/sign_in/ES-1-776053302069/home/",
#     "sitedomain": "srv-caixabanknow-sign-es.com",
#     "pagetitle": "Cai\u00d1 aBank | banca digital Cai\u00d1 aBankNow",
#     "firstseentime": "2021-12-29T15:05:34Z",
#     "firstseencode": "timeout",
#     "ipaddress": "192.185.151.24",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://e-caixabanknow-acces-es.net/sign_in/ES-1-77605815012077/home/",
#     "sitedomain": "e-caixabanknow-acces-es.net",
#     "pagetitle": "404 - PAGE NOT FOUND",
#     "firstseentime": "2021-12-27T18:00:01Z",
#     "firstseencode": "404",
#     "ipaddress": "192.185.165.92",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://skart.co.in/admin/webmail.cpanel.net/user/cp.user.sign_in/auth/cpanel_mailbox/index.htm",
#     "sitedomain": "skart.co.in",
#     "pagetitle": "Webmail Login",
#     "firstseentime": "2021-12-16T18:33:24Z",
#     "firstseencode": "200",
#     "ipaddress": "43.225.53.210",
#     "asn": "394695",
#     "asndesc": "PUBLIC-DOMAIN-REGISTRY, US",
#     "asnreg": "apnic",
#     "extracted_emails": "pentestmonkey@pentestmonkey.net, openfoxxthemes@gmail.com, check@isnotspam.com, leafot@gmail.com, anthon.pang@gmail.com, traveltino@gmail.com, oyejorge@gmail.com, nicolas.francois@frog-labs.com, Contact@company.com, email@storeaddress.com, info@OpenCartArab.com, florinpatan@gmail.com, fabien@symfony.com, andrew@noop.lv, arnaud.lb@gmail.com, martin.hason@gmail.com, drak@zikula.org, chabotc@google.com, slangley@google.com, beaton@google.com, jon.wayne.parrott@gmail.com, someuser@example.com, chirags@google.com, elsigh@google.com, openfoxin@gmail.com, user@example.com, iam.asm89@gmail.com, stloyd@gmail.com, fran6co@gmail.com, zoujingli@qq.com, BackEndTea@gmail.com, p@tchwork.com, a.aitboudad@gmail.com, kontakt@beberlei.de, michelsalib@hotmail.com, jeanfrancois.simon@sensiolabs.com, contact@jfsimon.fr, michael.lee@zerustech.com, marcosdsanchez@gmail.com, bschussek@gmail.com, clemens@build2be.nl, gtelegin@gmail.com, umpirsky@gmail.com, benjamin.dulau@gmail.com, daniel@danielholmes.org, manu@sprain.ch, michael.vhirsch@gmail.com, miha.vrhovnik@pagein.si, colinodell@gmail.com, thewholelifetolearn@gmail.com, t.nagel@infinite.net.au, florian@eckerstorfer.org, aj@garcialagar.es, bschussek@symfony.com, example@example.co.uk, fabien_potencier@example.fr, foo@example.com, foo@bar.fr, password@symfony.com, pass.word@symfony.com, user-name@symfony.com, error@example.com, florian@voutzinos.com, mallluhuct@gmail.com, naderman@naderman.de, j.boggiano@seld.be, hallsten@me.com, support@divido.com, smith@example.com, mike.jones@example.com, old.email@example.com, new.email@example.com, joe.martin@example.com, timmy@example.com, jane.doe@example.com, joe@bloggs.com, billgates@outlook.com, john.doe@example.com, check@this.com, dan@example.com, name@email.com, payer@example.com, payee@example.com, sandworm@example.com, john@smith.com"
#   },
#   {
#     "siteurl": "http://houkadaigakuin.com/css/webmail.konsoleh.co.za/emailSignIn_accountCUST_ID/konsoleh.sign_in/email.user/webmail.konsoleh.login.htm",
#     "sitedomain": "houkadaigakuin.com",
#     "pagetitle": "konsoleH\u2122 Webmail",
#     "firstseentime": "2021-11-10T14:27:35Z",
#     "firstseencode": "200",
#     "ipaddress": "182.48.49.73",
#     "asn": "9371",
#     "asndesc": "SAKURA-C SAKURA Internet Inc., JP",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://kitchenboutique.vietnamshops.com/login.microsoft.com/auth/user_office365/microsoft.css/sign_in/index.htm%2522",
#     "sitedomain": "kitchenboutique.vietnamshops.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-11-08T11:58:12Z",
#     "firstseencode": "404",
#     "ipaddress": "66.42.56.72",
#     "asn": "20473",
#     "asndesc": "AS-CHOOPA, US",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://m-caixabank-activar-tarjetas.com/sign_in/ES770109584469/home",
#     "sitedomain": "m-caixabank-activar-tarjetas.com",
#     "pagetitle": null,
#     "firstseentime": "2021-10-22T16:51:38Z",
#     "firstseencode": "aborted",
#     "ipaddress": "192.185.165.90",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://id.moneyforward.com/sign_in/email%3Fclient_id%3DOdII7gHa4v8Oouz6IbXSdRrVkTdbdzyISbOdEpEv070%26nonce%3D",
#     "sitedomain": "id.moneyforward.com",
#     "pagetitle": "\u30de\u30cd\u30fc\u30d5\u30a9\u30ef\u30fc\u30c9 ID",
#     "firstseentime": "2021-10-14T22:43:44Z",
#     "firstseencode": "404",
#     "ipaddress": "52.69.41.29",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/e6274ecd9ef7ffe/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": null,
#     "firstseentime": "2021-10-14T02:29:18Z",
#     "firstseencode": "timeout",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/6290852f28ee764/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:32:03Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/02a9dbf3c0f3070/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:31:49Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/66d8a96b3032f9a/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:31:46Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/048b14d665c1118/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:31:41Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/a8fca0f7d149a76/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:31:39Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/10deb071ce75a84/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:31:36Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://servicesclients.com.51543773-28-20210523142343.webstarterz.com/vers/da4a04eeac92d4e/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "servicesclients.com.51543773-28-20210523142343.webstarterz.com",
#     "pagetitle": "404 Not Found",
#     "firstseentime": "2021-10-13T01:31:02Z",
#     "firstseencode": "404",
#     "ipaddress": "163.44.198.42",
#     "asn": "135161",
#     "asndesc": "GMO-Z-COM-TH GMO-Z com NetDesign Holdings Co., Ltd., SG",
#     "asnreg": "apnic",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://online.panamarbank.com/sign_in/%3Fredirect_to%3Dhttps%253A%252F%252Fwww.online.panamarbank.com%252F",
#     "sitedomain": "online.panamarbank.com",
#     "pagetitle": "Page not found \u2013 Panama R Bank Online",
#     "firstseentime": "2021-10-02T19:22:48Z",
#     "firstseencode": "aborted",
#     "ipaddress": "162.241.226.115",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://nonslip19.github.io/Sign_In/",
#     "sitedomain": "nonslip19.github.io",
#     "pagetitle": null,
#     "firstseentime": "2021-10-02T12:48:55Z",
#     "firstseencode": "200",
#     "ipaddress": "185.199.108.153",
#     "asn": "54113",
#     "asndesc": "FASTLY, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://my.amarkets.trade/users/sign_in/%3Flocale%3Did%26g%3D39770",
#     "sitedomain": "my.amarkets.trade",
#     "pagetitle": "Please Wait... | Cloudflare",
#     "firstseentime": "2021-09-18T10:44:52Z",
#     "firstseencode": "403",
#     "ipaddress": "172.67.137.176",
#     "asn": "13335",
#     "asndesc": "CLOUDFLARENET, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://admire.social/pdf_document.file/viewpdfOnline.sign_in/sign_in.authorize.html",
#     "sitedomain": "admire.social",
#     "pagetitle": "None",
#     "firstseentime": "2021-09-17T02:02:37Z",
#     "firstseencode": "200",
#     "ipaddress": "92.53.96.111",
#     "asn": "9123",
#     "asndesc": "TIMEWEB-AS, RU",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.restorationfitness.com/users/sign_in/",
#     "sitedomain": "login.restorationfitness.com",
#     "pagetitle": "Log In | Restoration Fitness",
#     "firstseentime": "2021-09-12T03:26:53Z",
#     "firstseencode": "200",
#     "ipaddress": "142.250.74.211",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://adminko.money-stars.com/accounts/sign_in/%3Fnext%3D/",
#     "sitedomain": "adminko.money-stars.com",
#     "pagetitle": "Attention Required! | Cloudflare",
#     "firstseentime": "2021-09-08T12:54:04Z",
#     "firstseencode": "403",
#     "ipaddress": "203.24.109.188",
#     "asn": "209242",
#     "asndesc": "CLOUDFLARESPECTRUM Cloudflare, Inc., US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://adifakathy.github.io/Final-year-project_Sign_In/",
#     "sitedomain": "adifakathy.github.io",
#     "pagetitle": "Sign In Form",
#     "firstseentime": "2021-09-07T19:57:45Z",
#     "firstseencode": "200",
#     "ipaddress": "185.199.108.153",
#     "asn": "54113",
#     "asndesc": "FASTLY, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://basishealth.thesmartcarestore.com/users/sign_in/",
#     "sitedomain": "basishealth.thesmartcarestore.com",
#     "pagetitle": "Tacton CPQ - The #1 Rated CPQ for Manufacturers",
#     "firstseentime": "2021-08-27T08:15:08Z",
#     "firstseencode": "200",
#     "ipaddress": "142.250.74.211",
#     "asn": "15169",
#     "asndesc": "GOOGLE, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://bitrix24public.com/b24-n75jcq.bitrix24.com/form/1_sign_in/2b191j/",
#     "sitedomain": "bitrix24public.com",
#     "pagetitle": "Bitrix24 account does not exist or has been deleted",
#     "firstseentime": "2021-08-26T20:58:56Z",
#     "firstseencode": "403",
#     "ipaddress": "52.29.77.149",
#     "asn": "16509",
#     "asndesc": "AMAZON-02, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://login.microsoftonline.com/te/mgmasso.onmicrosoft.com/b2c_1_sign_up_sign_in/oauth2/v2.0/authorize%3Fclient_id%3Dfa945071-060d-48c6-b718-cca3f1e57323%26redirect_uri%3Dhttps%253A%252F%252Fmgmassoprod.azurewebsites.net%252Fsignin-oidc%26response_type%3Dcode%2520id_token%26scope%3Dopenid%2520profile%2520offline_access%2520https%253A%252F%252Fmgmasso.onmicrosoft.com%252FMGMAWebApi%252FAltaiRead%2520https%253A%252F%252Fmgmasso.onmicrosoft.com%252FMGMAWebApi%252FAltaiWrite%2520https%253A%252F%252Fmgmasso.onmicrosoft.com%252FMGMAWebApi%252FMGMARead%2520https%253A%252F%252Fmgmasso.onmicrosoft.com%252FMGMAWebApi%252FMGMAWrite%26response_mode%3Dform_post%26nonce%3D637655812672174496.N2E3MzBjMjQtNzBiMi00ODdmLTg0N2QtNWE1M2E4ZGJmN2YyOTFkNTc5NTUtZmI0YS00ZDI3LTgwMjgtNGQwZGM5N2EzN2I2%26state%3DCfDJ8O8G_cJsaCxNsGAbcg5vaK0TUaVlF5zk5z0xOZlECcKcMX4UcsDWOZzwKKKqGDHxiftvCn53TX2oZJxr3RveeewkHcAX-7vHj78WeCzhlpsEeV4j3uGs9r05ORQRvTwm_TQRK2O_dToI-oy1XYpAOi_LwqhJfdCXRoz37amJTuNt_JDkVmJnDAki1XEAs-MlETUVbUFAMtfnyF1ugemevTdxJDc7akZ4nV0Ss0sRfI1xlRAce1rUYJK7hWnB0dtra_mTMrnA8EN3DAu_OjRrZquuIozXFQ3ulh6MxbhOPaDvs6FVAv6zaaDCBbslOBpebE1Gn-K511sYNscu9PNFqrh8VokOs7bhH0vOO9LIBMGUB9z6BTJaBVF2O5hUuN9rgA%26x-client-SKU%3DID_NET%26x-client-ver%3D2.1.4.0",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2021-08-26T13:43:08Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.75",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://landandseacommercialrealty.com/wp-admin/user/outlook.office365/user.sign_in/ture_login/index.html",
#     "sitedomain": "landandseacommercialrealty.com",
#     "pagetitle": null,
#     "firstseentime": "2021-08-17T01:02:44Z",
#     "firstseencode": "406",
#     "ipaddress": "192.185.194.254",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://landandseacommercialrealty.com/wp-admin/user/outlook.office365/user.sign_in/ture_login/index.html",
#     "sitedomain": "landandseacommercialrealty.com",
#     "pagetitle": null,
#     "firstseentime": "2021-08-17T01:02:43Z",
#     "firstseencode": "406",
#     "ipaddress": "192.185.194.254",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://landandseacommercialrealty.com/wp-admin/user/outlook.office365/user.sign_in/ture_login/index.html",
#     "sitedomain": "landandseacommercialrealty.com",
#     "pagetitle": null,
#     "firstseentime": "2021-08-17T01:02:43Z",
#     "firstseencode": "406",
#     "ipaddress": "192.185.194.254",
#     "asn": "46606",
#     "asndesc": "UNIFIEDLAYER-AS-1, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "http://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/85789/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-08-07T02:17:46Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/4db90/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-08-07T02:17:06Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/168af/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-08-07T02:16:59Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://fahimxerxas.github.io/sign_in/",
#     "sitedomain": "fahimxerxas.github.io",
#     "pagetitle": null,
#     "firstseentime": "2021-08-05T12:17:20Z",
#     "firstseencode": "200",
#     "ipaddress": "185.199.109.153",
#     "asn": "54113",
#     "asndesc": "FASTLY, US",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://shivdeepfundsandshares.com/sign_in/myaccount/identification",
#     "sitedomain": "shivdeepfundsandshares.com",
#     "pagetitle": null,
#     "firstseentime": "2021-08-04T02:44:27Z",
#     "firstseencode": "404",
#     "ipaddress": "178.18.248.180",
#     "asn": "51167",
#     "asndesc": "CONTABO, DE",
#     "asnreg": "ripencc",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.anhna.com.mx/wp-content/uploads/2021/07/.webapp/vers/f9982d56f86a548/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "www.anhna.com.mx",
#     "pagetitle": null,
#     "firstseentime": "2021-07-30T18:28:27Z",
#     "firstseencode": "404",
#     "ipaddress": "3.227.24.127",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://www.anhna.com.mx/wp-content/uploads/2021/07/.webapp/vers/652d1482f90f217/sign_in/%3Fwebsrc%3D",
#     "sitedomain": "www.anhna.com.mx",
#     "pagetitle": null,
#     "firstseentime": "2021-07-30T09:54:58Z",
#     "firstseencode": "404",
#     "ipaddress": "3.227.24.127",
#     "asn": "14618",
#     "asndesc": "AMAZON-AES, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/168af/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-24T01:14:24Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/168af/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-24T01:14:23Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/0fd7c/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-24T01:12:16Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/0fd7c/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-24T01:12:16Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/85789/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-24T01:06:55Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/2b9a6/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-23T02:56:25Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
#   {
#     "siteurl": "https://thirsty-haibt.107-175-34-221.plesk.page/Sign_in/b622c/",
#     "sitedomain": "thirsty-haibt.107-175-34-221.plesk.page",
#     "pagetitle": null,
#     "firstseentime": "2021-07-23T02:10:40Z",
#     "firstseencode": "200",
#     "ipaddress": "107.175.34.221",
#     "asn": "36352",
#     "asndesc": "AS-COLOCROSSING, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   }
# ]

# %% [markdown]
# ### Observation for "/" test
# That worked! We can search for URLs with path elements (slashes) in them.

# %% [markdown]
# ### Observations for /url test
# We got 50 results for our simple test. Was that because we are limited to 50 results? Or because that was how many there were? We will need to test some more to find out.
#
# The format of results is shown below and is the same format as other results we have seen. So it seems there is one format for all search results. All API endpoints produce the same record type.
#
# `
# {
#     "siteurl": "https://login.microsoftonline.com/common/oauth2/authorize%3Fclient_id%3D00000002-0000-0ff1-ce00-000000000000%26redirect_uri%3Dhttps%253a%252f%252femail.o365.autodesk.com%252fowa%252f%26resource%3D00000002-0000-0ff1-ce00-000000000000%26response_mode%3Dform_post%26response_type%3Dcode%2Bid_token%26scope%3Dopenid%26msafed%3D0%26msaredir%3D0%26client-request-id%3D14e1a2bb-f887-0e4f-7951-b9009dea7b6f%26protectedtoken%3Dtrue%26claims%3D%257b%2522id_token%2522%253a%257b%2522xms_cc%2522%253a%257b%2522values%2522%253a%255b%2522CP1%2522%255d%257d%257d%257d%26nonce%3D637816299138232509.6d434649-a21f-4718-97dc-0f1c74fe5bdf%26state%3DfU9dT4MwAAT9LdsbjkIL9IGYYotBVxdI4xxvfBQzBhIHUrL_uf9j5w_wkrvkLncPZxqGca95p2naWgzfc_0AeA7GwA0c10E2fvBq6EIPYqtwQGNBHwQW9uvKshtQ-bCRqKwbU2-v5mZQxeYxmWSf0JAQfiI0veRt3PP-pd0K5nLBpjdaXQ5HG-1EprOozWne7QSDeZuqQxo9kz88DeSV8q8SKYFY7rMyWz7eVaSilRPvoSoXtD-LYjuzPtFJLCemR-yb3Bwh_7X4CZUR1u2VS9dymcefcxeC9XyUqh9q2YWZLGoux7H4lLcrvw%26sso_reload%3Dtrue",
#     "sitedomain": "login.microsoftonline.com",
#     "pagetitle": "Bad Request",
#     "firstseentime": "2022-02-28T07:45:06Z",
#     "firstseencode": "400",
#     "ipaddress": "20.190.160.132",
#     "asn": "8075",
#     "asndesc": "MICROSOFT-CORP-MSN-AS-BLOCK, US",
#     "asnreg": "arin",
#     "extracted_emails": null
#   },
# `
#
# An important question is, "What do these records reprensent?" What is the taxonomy?
#
# Take a look at the record above. Is the siteurl the URL for a phishing site? Or for a URL that redirects to a phishing site? It looks like it redirects to an autodesk.com URL.
#
# When I am investigating a phish, I often when to distinguish the URL delivered to the victim (via email for example), all of the domains that redirect, as well as the final "landing page" URL the victim is redirected to. In addition to that, some of these pages are just MITM proxies, and whenever possible it is nice to know the site they are proxying for.
